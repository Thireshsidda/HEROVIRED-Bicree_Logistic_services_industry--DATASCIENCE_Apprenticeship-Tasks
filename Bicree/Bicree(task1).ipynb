# %% [markdown]
# ### Company Information:
# Bicree is a 3PL AI tech enabled logistic aggregator platform, which provides customers
# with quality automated shipping solutions. Its services offer opportunities to ship
# anywhere in India. Bicree’s AI-powered dashboard is highly compatible with most
# e-commerce platforms and marketplaces. It is also integrable with custom websites and
# offers rest APIs.
# Bicree’s leading and specialized shipping partners ensure a safe and fast order delivery
# across varying volumes, type or size. It provides shipping across multiple segments
# ranging from apparels to electronics. Their platform helps in monitoring orders easily
# and increase profitability. It allows customers to analyze, connect, shipping assistance,
# auto NDR, COD Verification and Geo Analysis.

# %% [markdown]
# ### Task : Data Cleaning
# Data cleaning, or data wrangling or data remediation, or data munging,
# refers to a variety of processes designed to transform raw data into more readily used
# formats. It is the method of cleaning, arranging, and enriching raw information into the
# desired format for better decision-making in less time. The exact methods differ from
# project to project depending on the data you’re leveraging and the goal you’re trying to
# achieve.

# %% [markdown]
# ### Importing required libraries

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=(18,7)

# %% [markdown]
# ### Importing Dataset

# %%
df=pd.read_csv(r"C:\Users\rakes\Downloads\Bicree_shipment- test - SCMS_Delivery_History_Dataset.csv")
pd.set_option('display.max_columns', None)
df.head(25)
# Out:
#      ID Project Code            PQ #   PO / SO # ASN/DN #        Country  \
# 0     1   100-CI-T01  Pre-PQ Process      SCMS-4    ASN-8  Côte d'Ivoire
# 1     3   108-VN-T01  Pre-PQ Process     SCMS-13   ASN-85        Vietnam
# 2     4   100-CI-T01  Pre-PQ Process     SCMS-20   ASN-14  Côte d'Ivoire
# 3    15   108-VN-T01  Pre-PQ Process     SCMS-78   ASN-50        Vietnam
# 4    16   108-VN-T01  Pre-PQ Process     SCMS-81   ASN-55        Vietnam
# 5    23   112-NG-T01  Pre-PQ Process     SCMS-87   ASN-57        Nigeria
# 6    44   110-ZM-T01  Pre-PQ Process    SCMS-139  ASN-130         Zambia
# 7    45   109-TZ-T01  Pre-PQ Process    SCMS-140   ASN-94       Tanzania
# 8    46   112-NG-T01  Pre-PQ Process    SCMS-156   ASN-93        Nigeria
# 9    47   110-ZM-T01  Pre-PQ Process    SCMS-165  ASN-199         Zambia
# 10   60   110-ZM-T01  Pre-PQ Process    SCMS-221  ASN-223         Zambia
# 11   61   110-ZM-T01  Pre-PQ Process    SCMS-226  ASN-137         Zambia
# 12   62   102-NG-T01  Pre-PQ Process    SCMS-230  ASN-144        Nigeria
# 13   64   107-RW-T01  Pre-PQ Process    SCMS-268  ASN-242         Rwanda
# 14   65   106-HT-T01  Pre-PQ Process    SCMS-274  ASN-162          Haiti
# 15   68   113-ZW-T01  Pre-PQ Process    SCMS-308  ASN-285       Zimbabwe
# 16   69   102-NG-T01  Pre-PQ Process    SCMS-354  ASN-608        Nigeria
# 17   80   107-RW-T01  Pre-PQ Process    SCMS-488  ASN-299         Rwanda
# 18   87   109-TZ-T01  Pre-PQ Process    SCMS-555  ASN-409       Tanzania
# 19   92   102-NG-T01  Pre-PQ Process    SCMS-592  ASN-485        Nigeria
# 20   96   102-NG-T01  Pre-PQ Process    SCMS-570  ASN-451        Nigeria
# 21  108   104-CI-T01  Pre-PQ Process    SCMS-698  ASN-727  Côte d'Ivoire
# 22  115   108-VN-T01  Pre-PQ Process    SCMS-753  ASN-781        Vietnam
# 23  116   108-VN-T01  Pre-PQ Process    SCMS-759  ASN-632        Vietnam
# 24  130   100-HT-T01  Pre-PQ Process  SCMS-10080  ASN-628          Haiti
#
#    Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 0    PMO - US  Direct Drop              EXW           Air
# 1    PMO - US  Direct Drop              EXW           Air
# 2    PMO - US  Direct Drop              FCA           Air
# 3    PMO - US  Direct Drop              EXW           Air
# 4    PMO - US  Direct Drop              EXW           Air
# 5    PMO - US  Direct Drop              EXW           Air
# 6    PMO - US  Direct Drop              DDU           Air
# 7    PMO - US  Direct Drop              EXW           Air
# 8    PMO - US  Direct Drop              EXW           Air
# 9    PMO - US  Direct Drop              CIP           Air
# 10   PMO - US  Direct Drop              CIP           Air
# 11   PMO - US  Direct Drop              EXW           Air
# 12   PMO - US  Direct Drop              EXW           Air
# 13   PMO - US  Direct Drop              EXW           Air
# 14   PMO - US  Direct Drop              EXW           Air
# 15   PMO - US  Direct Drop              CIP           Air
# 16   PMO - US  Direct Drop              CIP           NaN
# 17   PMO - US  Direct Drop              EXW           Air
# 18   PMO - US  Direct Drop              CIP           Air
# 19   PMO - US  Direct Drop              EXW           Air
# 20   PMO - US  Direct Drop              EXW           Air
# 21   PMO - US  Direct Drop              CIP           Air
# 22   PMO - US  Direct Drop              EXW           Air
# 23   PMO - US  Direct Drop              FCA           Air
# 24   PMO - US  Direct Drop              EXW           Air
#
#    PQ First Sent to Client Date PO Sent to Vendor Date  \
# 0                Pre-PQ Process      Date Not Captured
# 1                Pre-PQ Process      Date Not Captured
# 2                Pre-PQ Process      Date Not Captured
# 3                Pre-PQ Process      Date Not Captured
# 4                Pre-PQ Process      Date Not Captured
# 5                Pre-PQ Process      Date Not Captured
# 6                Pre-PQ Process      Date Not Captured
# 7                Pre-PQ Process      Date Not Captured
# 8                Pre-PQ Process      Date Not Captured
# 9                Pre-PQ Process               11/13/06
# 10               Pre-PQ Process                12/1/06
# 11               Pre-PQ Process      Date Not Captured
# 12               Pre-PQ Process      Date Not Captured
# 13               Pre-PQ Process               12/22/06
# 14               Pre-PQ Process      Date Not Captured
# 15               Pre-PQ Process                1/10/07
# 16               Pre-PQ Process      Date Not Captured
# 17               Pre-PQ Process      Date Not Captured
# 18               Pre-PQ Process                4/12/07
# 19               Pre-PQ Process                5/13/07
# 20               Pre-PQ Process                5/17/07
# 21               Pre-PQ Process                7/13/07
# 22               Pre-PQ Process                 7/4/07
# 23               Pre-PQ Process                 7/4/07
# 24               Pre-PQ Process                7/26/07
#
#    Scheduled Delivery Date Delivered to Client Date Delivery Recorded Date  \
# 0                 2-Jun-06                 2-Jun-06               2-Jun-06
# 1                14-Nov-06                14-Nov-06              14-Nov-06
# 2                27-Aug-06                27-Aug-06              27-Aug-06
# 3                 1-Sep-06                 1-Sep-06               1-Sep-06
# 4                11-Aug-06                11-Aug-06              11-Aug-06
# 5                28-Sep-06                28-Sep-06              28-Sep-06
# 6                 8-Jan-07                 8-Jan-07               8-Jan-07
# 7                24-Nov-06                24-Nov-06              24-Nov-06
# 8                 7-Dec-06                 7-Dec-06               7-Dec-06
# 9                30-Jan-07                30-Jan-07              30-Jan-07
# 10               16-Feb-07                16-Feb-07              16-Feb-07
# 11                8-Jan-07                 8-Jan-07               8-Jan-07
# 12               10-Jan-07                10-Jan-07              10-Jan-07
# 13               27-Feb-07                27-Feb-07              27-Feb-07
# 14               18-Jan-07                18-Jan-07              18-Jan-07
# 15               19-Mar-07                19-Mar-07              19-Mar-07
# 16                7-May-07                 7-May-07               7-May-07
# 17               29-Mar-07                29-Mar-07              29-Mar-07
# 18                6-Jun-07                 6-Jun-07               6-Jun-07
# 19               19-Jun-07                19-Jun-07              19-Jun-07
# 20               19-Jun-07                19-Jun-07              19-Jun-07
# 21                2-Oct-07                 2-Oct-07               2-Oct-07
# 22               15-Oct-07                15-Oct-07              15-Oct-07
# 23               27-Aug-07                27-Aug-07              27-Aug-07
# 24               13-Aug-07                21-Aug-07              21-Aug-07
#
#    Product Group Sub Classification  \
# 0           HRDT           HIV test
# 1            ARV          Pediatric
# 2           HRDT           HIV test
# 3            ARV              Adult
# 4            ARV              Adult
# 5            ARV          Pediatric
# 6            ARV          Pediatric
# 7            ARV              Adult
# 8            ARV              Adult
# 9            ARV              Adult
# 10           ARV              Adult
# 11          HRDT           HIV test
# 12          HRDT           HIV test
# 13           ARV              Adult
# 14          HRDT           HIV test
# 15           ARV          Pediatric
# 16          HRDT           HIV test
# 17          HRDT           HIV test
# 18           ARV          Pediatric
# 19          HRDT           HIV test
# 20          HRDT           HIV test
# 21           ARV          Pediatric
# 22           ARV          Pediatric
# 23           ARV              Adult
# 24          HRDT           HIV test
#
#                                                Vendor  \
# 0                         RANBAXY Fine Chemicals LTD.
# 1                            Aurobindo Pharma Limited
# 2                                Abbott GmbH & Co. KG
# 3   SUN PHARMACEUTICAL INDUSTRIES LTD (RANBAXY LAB...
# 4                            Aurobindo Pharma Limited
# 5                            Aurobindo Pharma Limited
# 6   MERCK SHARP & DOHME IDEA GMBH (FORMALLY MERCK ...
# 7                            Aurobindo Pharma Limited
# 8                            Aurobindo Pharma Limited
# 9     ABBVIE LOGISTICS (FORMERLY ABBOTT LOGISTICS BV)
# 10    ABBVIE LOGISTICS (FORMERLY ABBOTT LOGISTICS BV)
# 11                               Trinity Biotech, Plc
# 12                                    EY Laboratories
# 13                                      CIPLA LIMITED
# 14                               Abbott GmbH & Co. KG
# 15                               BRISTOL-MYERS SQUIBB
# 16                             ACCOUN NIGERIA LIMITED
# 17                   Premier Medical Corporation Ltd.
# 18                               BRISTOL-MYERS SQUIBB
# 19                               Abbott GmbH & Co. KG
# 20                   CHEMBIO DIAGNOSTIC SYSTEMS, INC.
# 21                               BRISTOL-MYERS SQUIBB
# 22                           Aurobindo Pharma Limited
# 23    ABBVIE LOGISTICS (FORMERLY ABBOTT LOGISTICS BV)
# 24                                      Orgenics, Ltd
#
#                                      Item Description  \
# 0   HIV, Reveal G3 Rapid HIV-1 Antibody Test, 30 T...
# 1   Nevirapine 10mg/ml, oral suspension, Bottle, 2...
# 2      HIV 1/2, Determine Complete HIV Kit, 100 Tests
# 3                  Lamivudine 150mg, tablets, 60 Tabs
# 4                   Stavudine 30mg, capsules, 60 Caps
# 5   Zidovudine 10mg/ml, oral solution, Bottle, 240 ml
# 6   Efavirenz 200mg [Stocrin/Sustiva], capsule, 90...
# 7                  Nevirapine 200mg, tablets, 60 Tabs
# 8                   Stavudine 30mg, capsules, 60 Caps
# 9   Lopinavir/Ritonavir 200/50mg [Aluvia], tablets...
# 10  Lopinavir/Ritonavir 200/50mg [Aluvia], tablets...
# 11                HIV 1/2, Uni-Gold HIV Kit, 20 Tests
# 12        HIV 1/2, InstantChek HIV 1+2 Kit, 100 Tests
# 13  Lamivudine/Zidovudine 150/300mg, tablets, 60 Tabs
# 14     HIV 1/2, Determine Complete HIV Kit, 100 Tests
# 15  #102198**Didanosine 200mg [Videx], tablets, 60...
# 16     HIV 1/2, Determine Complete HIV Kit, 100 Tests
# 17  HIV 1/2/O, First Response HIV 1-2.0, v.3.0 Car...
# 18  Didanosine 2g [Videx], powder for oral solutio...
# 19     HIV 1/2, Determine Complete HIV Kit, 100 Tests
# 20               HIV 1/2, Stat-Pak HIV, Kit, 20 Tests
# 21  #102198**Didanosine 200mg [Videx], tablets, 60...
# 22  Nevirapine 10mg/ml, oral suspension, Bottle, 2...
# 23  Lopinavir/Ritonavir 200/50mg [Aluvia], tablets...
# 24  HIV 1/2, Determine HIV Kit, without Lancets, 1...
#
#                                    Molecule/Test Type            Brand  \
# 0            HIV, Reveal G3 Rapid HIV-1 Antibody Test           Reveal
# 1                                          Nevirapine          Generic
# 2                 HIV 1/2, Determine Complete HIV Kit        Determine
# 3                                          Lamivudine          Generic
# 4                                           Stavudine          Generic
# 5                                          Zidovudine          Generic
# 6                                           Efavirenz  Stocrin/Sustiva
# 7                                          Nevirapine          Generic
# 8                                           Stavudine          Generic
# 9                                 Lopinavir/Ritonavir           Aluvia
# 10                                Lopinavir/Ritonavir           Aluvia
# 11                          HIV 1/2, Uni-Gold HIV Kit         Uni-Gold
# 12                   HIV 1/2, InstantChek HIV 1+2 Kit      InstantCHEK
# 13                              Lamivudine/Zidovudine          Generic
# 14                HIV 1/2, Determine Complete HIV Kit        Determine
# 15                                         Didanosine            Videx
# 16                HIV 1/2, Determine Complete HIV Kit        Determine
# 17  HIV 1/2/O, First Response HIV 1-2.0, v.3.0 Car...   First Response
# 18                                         Didanosine            Videx
# 19                HIV 1/2, Determine Complete HIV Kit        Determine
# 20                         HIV 1/2, Stat-Pak HIV, Kit         Stat-Pak
# 21                                         Didanosine            Videx
# 22                                         Nevirapine          Generic
# 23                                Lopinavir/Ritonavir           Aluvia
# 24        HIV 1/2, Determine HIV Kit, without Lancets        Determine
#
#        Dosage               Dosage Form  Unit of Measure (Per Pack)  \
# 0         NaN                  Test kit                          30
# 1     10mg/ml           Oral suspension                         240
# 2         NaN                  Test kit                         100
# 3       150mg                    Tablet                          60
# 4        30mg                   Capsule                          60
# 5     10mg/ml             Oral solution                         240
# 6       200mg                   Capsule                          90
# 7       200mg                    Tablet                          60
# 8        30mg                   Capsule                          60
# 9    200/50mg                    Tablet                         120
# 10   200/50mg                    Tablet                         120
# 11        NaN                  Test kit                          20
# 12        NaN                  Test kit                         100
# 13  150/300mg              Tablet - FDC                          60
# 14        NaN                  Test kit                         100
# 15      200mg                    Tablet                          60
# 16        NaN                  Test kit                         100
# 17        NaN                  Test kit                          30
# 18         2g  Powder for oral solution                         200
# 19        NaN                  Test kit                         100
# 20        NaN                  Test kit                          20
# 21      200mg                    Tablet                          60
# 22    10mg/ml           Oral suspension                         240
# 23   200/50mg                    Tablet                         120
# 24        NaN                  Test kit                         100
#
#     Line Item Quantity  Line Item Value  Pack Price  Unit Price  \
# 0                   19           551.00       29.00        0.97
# 1                 1000          6200.00        6.20        0.03
# 2                  500         40000.00       80.00        0.80
# 3                31920        127360.80        3.99        0.07
# 4                38000        121600.00        3.20        0.05
# 5                  416          2225.60        5.35        0.02
# 6                  135          4374.00       32.40        0.36
# 7                16667         60834.55        3.65        0.06
# 8                  273           532.35        1.95        0.03
# 9                 2800        115080.00       41.10        0.34
# 10                2800        115080.00       41.10        0.34
# 11                2500        100000.00       40.00        2.00
# 12                  10           850.00       85.00        0.85
# 13               10000         99800.00        9.98        0.17
# 14                 750         60000.00       80.00        0.80
# 15                 579         14764.50       25.50        0.42
# 16                1500        120000.00       80.00        0.80
# 17                2000         33000.00       16.50        0.55
# 18                 712          8964.08       12.59        0.06
# 19                1000         80000.00       80.00        0.80
# 20                7500        202500.00       27.00        1.35
# 21                5513        140581.50       25.50        0.42
# 22                1000          1920.00        1.92        0.01
# 23                 500         41095.00       82.19        0.68
# 24                 750         53992.50       71.99        0.72
#
#                 Manufacturing Site First Line Designation  \
# 0       Ranbaxy Fine Chemicals LTD                    Yes
# 1        Aurobindo Unit III, India                    Yes
# 2    ABBVIE GmbH & Co.KG Wiesbaden                    Yes
# 3    Ranbaxy, Paonta Shahib, India                    Yes
# 4        Aurobindo Unit III, India                    Yes
# 5        Aurobindo Unit III, India                    Yes
# 6    MSD South Granville Australia                    Yes
# 7        Aurobindo Unit III, India                    Yes
# 8        Aurobindo Unit III, India                     No
# 9   ABBVIE (Abbott) St. P'burg USA                    Yes
# 10     ABBVIE Ludwigshafen Germany                    Yes
# 11            Trinity Biotech, Plc                    Yes
# 12            EY Laboratories, USA                    Yes
# 13               Cipla, Goa, India                    Yes
# 14   ABBVIE GmbH & Co.KG Wiesbaden                    Yes
# 15              BMS Meymac, France                    Yes
# 16   ABBVIE GmbH & Co.KG Wiesbaden                    Yes
# 17    Premier Med. Corp Ltd. India                    Yes
# 18              BMS Meymac, France                    Yes
# 19   ABBVIE GmbH & Co.KG Wiesbaden                    Yes
# 20   Chembio Diagnostics Sys. Inc.                    Yes
# 21              BMS Meymac, France                    Yes
# 22       Aurobindo Unit III, India                    Yes
# 23     ABBVIE Ludwigshafen Germany                    Yes
# 24                 Inverness Japan                    Yes
#
#             Weight (Kilograms)                  Freight Cost (USD)  \
# 0                           13                              780.34
# 1                          358                              4521.5
# 2                          171                             1653.78
# 3                         1855                            16007.06
# 4                         7590                            45450.08
# 5                          504                             5920.42
# 6                          328  Freight Included in Commodity Cost
# 7                         1478                             6212.41
# 8        See ASN-93 (ID#:1281)               See ASN-93 (ID#:1281)
# 9                          643  Freight Included in Commodity Cost
# 10                         643  Freight Included in Commodity Cost
# 11                         853                            13569.49
# 12  Weight Captured Separately                 Invoiced Separately
# 13                        7416                            64179.42
# 14                         256                             1760.32
# 15  Weight Captured Separately  Freight Included in Commodity Cost
# 16  Weight Captured Separately  Freight Included in Commodity Cost
# 17                         710                              3120.7
# 18                         162                              912.96
# 19                         341                             2682.47
# 20                        2278                            15893.71
# 21                        2126  Freight Included in Commodity Cost
# 22                         941                             4193.49
# 23                         117                             1767.38
# 24                         171                             3518.38
#
#     Line Item Insurance (USD)
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16                     192.00
# 17                        NaN
# 18                        NaN
# 19                     128.00
# 20                        NaN
# 21                     224.93
# 22                       3.07
# 23                      65.75
# 24                      86.39

# %% [markdown]
# ### Checking the number of rows and columns

# %%
df.shape
print('In this provided data we have {} number of Rows and {} number of columns'.format(df.shape[0],df.shape[1]))
# Out:
# In this provided data we have 10324 number of Rows and 33 number of columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10324 entries, 0 to 10323
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            10324 non-null  int64
#  1   Project Code                  10324 non-null  object
#  2   PQ #                          10324 non-null  object
#  3   PO / SO #                     10324 non-null  object
#  4   ASN/DN #                      10324 non-null  object
#  5   Country                       10324 non-null  object
#  6   Managed By                    10324 non-null  object
#  7   Fulfill Via                   10324 non-null  object
#  8   Vendor INCO Term              10324 non-null  object
#  9   Shipment Mode                 9964 non-null   object
#  10  PQ First Sent to Client Date  10324 non-null  object
#  11  PO Sent to Vendor Date        10324 non-null  object
#  12  Scheduled Delivery Date       10324 non-null  object
#  13  Delivered to Client Date      10324 non-null  object
#  14  Delivery Recorded Date        10324 non-null  object
#  15  Product Group                 10324 non-null  object
#  16  Sub Classification            10324 non-null  object
#  17  Vendor                        10324 non-null  object
#  18  Item Description              10324 non-null  object
#  19  Molecule/Test Type            10324 non-null  object
#  20  Brand                         10324 non-null  object
#  21  Dosage                        8588 non-null   object
#  22  Dosage Form                   10324 non-null  object
#  23  Unit of Measure (Per Pack)    10324 non-null  int64
#  24  Line Item Quantity            10324 non-null  int64
#  25  Line Item Value               10324 non-null  float64
#  26  Pack Price                    10324 non-null  float64
#  27  Unit Price                    10324 non-null  float64
#  28  Manufacturing Site            10324 non-null  object
#  29  First Line Designation        10324 non-null  object
#  30  Weight (Kilograms)            10324 non-null  object
#  31  Freight Cost (USD)            10324 non-null  object
#  32  Line Item Insurance (USD)     10037 non-null  float64
# dtypes: float64(4), int64(3), object(26)
# memory usage: 2.6+ MB

# %% [markdown]
# ### Datatype of the features

# %%
df.dtypes
# Out:
# ID                                int64
# Project Code                     object
# PQ #                             object
# PO / SO #                        object
# ASN/DN #                         object
# Country                          object
# Managed By                       object
# Fulfill Via                      object
# Vendor INCO Term                 object
# Shipment Mode                    object
# PQ First Sent to Client Date     object
# PO Sent to Vendor Date           object
# Scheduled Delivery Date          object
# Delivered to Client Date         object
# Delivery Recorded Date           object
# Product Group                    object
# Sub Classification               object
# Vendor                           object
# Item Description                 object
# Molecule/Test Type               object
# Brand                            object
# Dosage                           object
# Dosage Form                      object
# Unit of Measure (Per Pack)        int64
# Line Item Quantity                int64
# Line Item Value                 float64
# Pack Price                      float64
# Unit Price                      float64
# Manufacturing Site               object
# First Line Designation           object
# Weight (Kilograms)               object
# Freight Cost (USD)               object
# Line Item Insurance (USD)       float64
# dtype: object

# %% [markdown]
# ### Columns of the data

# %%
columns=df.columns
columns
# Out:
# Index(['ID', 'Project Code', 'PQ #', 'PO / SO #', 'ASN/DN #', 'Country',
#        'Managed By', 'Fulfill Via', 'Vendor INCO Term', 'Shipment Mode',
#        'PQ First Sent to Client Date', 'PO Sent to Vendor Date',
#        'Scheduled Delivery Date', 'Delivered to Client Date',
#        'Delivery Recorded Date', 'Product Group', 'Sub Classification',
#        'Vendor', 'Item Description', 'Molecule/Test Type', 'Brand', 'Dosage',
#        'Dosage Form', 'Unit of Measure (Per Pack)', 'Line Item Quantity',
#        'Line Item Value', 'Pack Price', 'Unit Price', 'Manufacturing Site',
#        'First Line Designation', 'Weight (Kilograms)', 'Freight Cost (USD)',
#        'Line Item Insurance (USD)'],
#       dtype='object')

# %% [markdown]
# ### Categorical features

# %%
cat_feat=df.select_dtypes(include='object')
print("The categorical Features of the data are:",'\n',cat_feat.columns)
# Out:
# The categorical Features of the data are:
#  Index(['Project Code', 'PQ #', 'PO / SO #', 'ASN/DN #', 'Country',
#        'Managed By', 'Fulfill Via', 'Vendor INCO Term', 'Shipment Mode',
#        'PQ First Sent to Client Date', 'PO Sent to Vendor Date',
#        'Scheduled Delivery Date', 'Delivered to Client Date',
#        'Delivery Recorded Date', 'Product Group', 'Sub Classification',
#        'Vendor', 'Item Description', 'Molecule/Test Type', 'Brand', 'Dosage',
#        'Dosage Form', 'Manufacturing Site', 'First Line Designation',
#        'Weight (Kilograms)', 'Freight Cost (USD)'],
#       dtype='object')

# %% [markdown]
# ### Frequency of the categorical features

# %%
for i in cat_feat.columns:
    print(i,'\n',cat_feat[i].value_counts(),'\n')
# Out:
# Project Code
#  116-ZA-T30    768
# 104-CI-T30    729
# 151-NG-T30    628
# 114-UG-T30    596
# 108-VN-T30    522
#              ...
# 100-GN-T30      1
# 103-CD-T30      1
# 103-UG-T30      1
# 900-GY-T30      1
# 104-SZ-T30      1
# Name: Project Code, Length: 142, dtype: int64
#
# PQ #
#  Pre-PQ Process    2681
# FPQ-14942          205
# FPQ-12522          154
# FPQ-13973          110
# FPQ-4537            98
#                   ...
# FPQ-6977             1
# FPQ-9819             1
# FPQ-6124             1
# FPQ-12838            1
# FPQ-15884            1
# Name: PQ #, Length: 1237, dtype: int64
#
# PO / SO #
#  SCMS-199289    67
# SCMS-199283    63
# SCMS-183950    55
# SCMS-215370    38
# SCMS-259075    38
#                ..
# SO-47850        1
# SCMS-102040     1
# SCMS-103150     1
# SO-40490        1
# SCMS-134290     1
# Name: PO / SO #, Length: 6233, dtype: int64
#
# ASN/DN #
#  ASN-19166    54
# ASN-24415    38
# ASN-23875    26
# ASN-32138    19
# ASN-28036    17
#              ..
# ASN-15388     1
# ASN-6395      1
# ASN-10756     1
# ASN-29936     1
# DN-2406       1
# Name: ASN/DN #, Length: 7030, dtype: int64
#
# Country
#  South Africa          1406
# Nigeria               1194
# Côte d'Ivoire         1083
# Uganda                 779
# Vietnam                688
# Zambia                 683
# Haiti                  655
# Mozambique             631
# Zimbabwe               538
# Tanzania               519
# Rwanda                 430
# Congo, DRC             333
# Guyana                 237
# Ethiopia               216
# South Sudan            164
# Kenya                  111
# Burundi                 98
# Namibia                 95
# Cameroon                75
# Botswana                70
# Ghana                   58
# Dominican Republic      52
# Sudan                   46
# Swaziland               35
# Mali                    17
# Guatemala               15
# Pakistan                15
# Malawi                  14
# Benin                   13
# Libya                    8
# Lebanon                  8
# Angola                   7
# Liberia                  6
# Lesotho                  4
# Sierra Leone             4
# Togo                     3
# Afghanistan              3
# Senegal                  3
# Burkina Faso             2
# Kazakhstan               2
# Kyrgyzstan               2
# Guinea                   1
# Belize                   1
# Name: Country, dtype: int64
#
# Managed By
#  PMO - US                     10265
# South Africa Field Office       57
# Ethiopia Field Office            1
# Haiti Field Office               1
# Name: Managed By, dtype: int64
#
# Fulfill Via
#  From RDC       5404
# Direct Drop    4920
# Name: Fulfill Via, dtype: int64
#
# Vendor INCO Term
#  N/A - From RDC    5404
# EXW               2778
# DDP               1443
# FCA                397
# CIP                275
# DDU                 15
# DAP                  9
# CIF                  3
# Name: Vendor INCO Term, dtype: int64
#
# Shipment Mode
#  Air            6113
# Truck          2830
# Air Charter     650
# Ocean           371
# Name: Shipment Mode, dtype: int64
#
# PQ First Sent to Client Date
#  Pre-PQ Process       2476
# 9/11/14               205
# Date Not Captured     205
# 7/11/13               173
# 4/30/14               123
#                      ...
# 1/3/12                  1
# 4/3/11                  1
# 4/16/15                 1
# 5/31/12                 1
# 8/27/14                 1
# Name: PQ First Sent to Client Date, Length: 765, dtype: int64
#
# PO Sent to Vendor Date
#  N/A - From RDC       5404
# Date Not Captured     328
# 8/27/14                80
# 3/19/10                78
# 8/29/14                76
#                      ...
# 6/2/09                  1
# 11/2/10                 1
# 5/18/15                 1
# 7/6/11                  1
# 3/12/15                 1
# Name: PO Sent to Vendor Date, Length: 897, dtype: int64
#
# Scheduled Delivery Date
#  29-Aug-14    97
# 16-Mar-12    83
# 27-Aug-14    63
# 31-May-10    62
# 31-Jan-14    60
#              ..
# 14-May-13     1
# 25-Jun-07     1
# 19-May-15     1
# 3-Jan-13      1
# 9-Feb-15      1
# Name: Scheduled Delivery Date, Length: 2006, dtype: int64
#
# Delivered to Client Date
#  29-Aug-14    74
# 27-Aug-14    66
# 28-Jun-10    60
# 14-Feb-12    60
# 16-Apr-13    59
#              ..
# 18-Oct-07     1
# 20-Dec-10     1
# 21-Jul-12     1
# 10-May-06     1
# 31-Aug-12     1
# Name: Delivered to Client Date, Length: 2093, dtype: int64
#
# Delivery Recorded Date
#  29-Aug-14    67
# 27-Aug-14    66
# 28-Jun-10    60
# 14-Feb-12    60
# 16-Apr-13    59
#              ..
# 27-Apr-11     1
# 30-May-14     1
# 12-Dec-07     1
# 25-Oct-13     1
# 31-Aug-12     1
# Name: Delivery Recorded Date, Length: 2042, dtype: int64
#
# Product Group
#  ARV     8550
# HRDT    1728
# ANTM      22
# ACT       16
# MRDT       8
# Name: Product Group, dtype: int64
#
# Sub Classification
#  Adult                   6595
# Pediatric               1955
# HIV test                1567
# HIV test - Ancillary     161
# Malaria                   30
# ACT                       16
# Name: Sub Classification, dtype: int64
#
# Vendor
#  SCMS from RDC                           5404
# Orgenics, Ltd                            754
# S. BUYS WHOLESALER                       715
# Aurobindo Pharma Limited                 668
# Trinity Biotech, Plc                     356
#                                         ...
# OMEGA DIAGNOSTICS LTD                      1
# THE MEDICAL EXPORT GROUP BV                1
# CENTRAL PHARMACEUTICAL COMPANY NO. 1       1
# ACCESS BIO, INC.                           1
# RAININ INSTRUMENT, LLC.                    1
# Name: Vendor, Length: 73, dtype: int64
#
# Item Description
#  Efavirenz 600mg, tablets, 30 Tabs                                                755
# Nevirapine 200mg, tablets, 60 Tabs                                               623
# Lamivudine/Zidovudine 150/300mg, tablets, 60 Tabs                                597
# Lamivudine/Nevirapine/Zidovudine 150/200/300mg, tablets, 60 Tabs                 580
# HIV 1/2, Determine Complete HIV Kit, 100 Tests                                   577
#                                                                                 ...
# Lopinavir/Ritonavir 200/50mg, [DON] tablets, 120 Tabs                              1
# Mefloquine 250mg (as hydrochloride), tablets, 100 Tabs                             1
# HIV 1/2, Visitect Kit, 25 Tests                                                    1
# Efavirenz 200mg, tablets, 30 Tabs                                                  1
# Lamivudine/Zidovudine+Abacavir 150/300+300mg, tablets, co-blister, 60+60 Tabs      1
# Name: Item Description, Length: 184, dtype: int64
#
# Molecule/Test Type
#  Efavirenz                                                                                             1125
# Nevirapine                                                                                             877
# Lamivudine/Nevirapine/Zidovudine                                                                       707
# Lamivudine/Zidovudine                                                                                  689
# Lopinavir/Ritonavir                                                                                    633
#                                                                                                       ...
# HIV 1/2, ImmunoComb II BiSpot EIA Kit                                                                    1
# HIV 1/2, Visitect Kit                                                                                    1
# Quinine                                                                                                  1
# HIV 1/2, INSTI HIV 1/2 Antibody Kit                                                                      1
# HIV 1/2, Colloidal Gold, Diagnostic Kit Set (includes lancet, transfer pipette & alcohol prep pad)       1
# Name: Molecule/Test Type, Length: 86, dtype: int64
#
# Brand
#  Generic            7285
# Determine           799
# Uni-Gold            373
# Aluvia              250
# Kaletra             165
# Norvir              136
# Stat-Pak            115
# Bioline             113
# Truvada              94
# Videx                84
# Colloidal Gold       70
# Stocrin/Sustiva      69
# OraQuick             60
# Invirase             53
# Viread               52
# Zerit                46
# Isentress            44
# Epivir               42
# Prezista             42
# Retrovir             41
# Videx EC             41
# Ziagen               37
# Crixivan             36
# Capillus             35
# Intelence            32
# Genie                30
# Viramune             28
# Clearview            19
# Reyataz              18
# Trizivir             18
# Atripla              16
# First Response       15
# Coartem              12
# Viracept             11
# DoubleCheck           5
# Multispot             5
# Paramax               5
# INSTi                 5
# LAV                   4
# Hexagon               3
# Combivir              3
# ImmunoComb            3
# Reveal                3
# InstantCHEK           2
# Bundi                 2
# CareStart             1
# Visitect              1
# Pepti-LAV             1
# Name: Brand, dtype: int64
#
# Dosage
#  300mg              990
# 200mg              932
# 600mg              772
# 150/300mg          600
# 150/300/200mg      580
# 10mg/ml            552
# 150mg              431
# 200/50mg           395
# 300/300mg          301
# 600/300/300mg      286
# 150/200/30mg       250
# 100mg              228
# 50mg               174
# 200/300mg          160
# 80/20mg/ml         158
# 400mg              156
# 20mg/ml            152
# 30mg               144
# 600/200/300mg      139
# 150/30mg           133
# 30/50/60mg         127
# 300/200mg           94
# 30/60mg             89
# 250mg               88
# 100/25mg            73
# 60/30mg             73
# 600/300mg           63
# 1mg/ml              54
# 300/100mg           54
# 20mg                43
# 25mg                39
# 15mg                38
# 30mg/ml             33
# 300/150/300mg       28
# 30/50/6mg           19
# 30/6mg              14
# 500/25mg            13
# 80mg/ml             13
# 60/100/12mg         12
# 20/120mg            12
# 2g                  11
# 500mg               10
# 150/300+200mg        8
# 133.3/33.3mg         7
# 150/300mg+600mg      7
# 40mg                 6
# 150/200/40mg         5
# 60mg                 5
# 60/12mg              5
# 125mg                4
# 50+153mg             4
# 600mg/2ml            2
# 50mg/g               1
# 150/300+300mg        1
# Name: Dosage, dtype: int64
#
# Dosage Form
#  Tablet                                3532
# Tablet - FDC                          2749
# Test kit                              1575
# Capsule                                729
# Oral solution                          727
# Chewable/dispersible tablet - FDC      239
# Oral suspension                        214
# Test kit - Ancillary                   161
# Chewable/dispersible tablet            146
# Delayed-release capsules               131
# Delayed-release capsules - blister      41
# Powder for oral solution                28
# Tablet - FDC + co-blister               20
# Tablet - FDC + blister                  15
# Tablet - blister                        10
# Injection                                6
# Oral powder                              1
# Name: Dosage Form, dtype: int64
#
# Manufacturing Site
#  Aurobindo Unit III, India              3172
# Mylan (formerly Matrix) Nashik         1415
# Hetero Unit III Hyderabad IN            869
# Cipla, Goa, India                       665
# Strides, Bangalore, India.              540
#                                        ...
# BUNDI INTERNATIONAL DIAGNOSTICS LTD       1
# MedMira Inc.                              1
# Meditab (for Cipla) Daman IN              1
# Gland Pharma Ltd Pally Factory            1
# GSK Barnard Castle UK                     1
# Name: Manufacturing Site, Length: 88, dtype: int64
#
# First Line Designation
#  Yes    7030
# No     3294
# Name: First Line Designation, dtype: int64
#
# Weight (Kilograms)
#  Weight Captured Separately    1507
# 2                               29
# 6                               26
# 1                               23
# 5                               20
#                               ...
# 14340                            1
# 4382                             1
# See ASN-26283 (ID#:46875)        1
# See ASN-10816 (ID#:28664)        1
# 4091                             1
# Name: Weight (Kilograms), Length: 4688, dtype: int64
#
# Freight Cost (USD)
#  Freight Included in Commodity Cost    1442
# Invoiced Separately                    239
# 9736.1                                  36
# 6147.18                                 27
# 7445.8                                  16
#                                       ...
# See DN-3744 (ID#:85483)                  1
# See ASN-33146 (ID#:44860)                1
# 1400                                     1
# 729.03                                   1
# 1572.92                                  1
# Name: Freight Cost (USD), Length: 6733, dtype: int64

# %% [markdown]
# ### Detailed Description about the features:

# %% [markdown]
# ###### PQ(Perfomance qualification):
# It is the documented collection of activities necessary to demonstrate that an instrument consistently performs according to the specifications defined by the user and is appropriate for the intended use.

# %% [markdown]
# ###### PO (Purchase Order) (or) SO (Shipping Order):
# A purchase order (PO) is a document that represents an agreement with a vendor to buy goods or services
#
# (or)
#
# Shipping Order (SO) A document from the carrier that confirms that space for the cargo is booked onboard the vessel.

# %% [markdown]
# ###### ASN(Advanced Shipment Notice) / DN(Delivery Note):
# ASN: An advanced shipment notice (ASN) is an electronic data interchange (EDI) message sent from the shipper to the receiver prior to the departure of the shipment from the shipper's facility. The message includes complete information about the shipment and its contents.
#
# DN: It provides a list of the products and quantity of the goods included in the deliver.

# %% [markdown]
# ##### Country:
# The country which the product is shipping from.

# %% [markdown]
# ###### Managed by:
# The particular shipment that is managed by the office i.e, Project Management Office.
#
# We have four management offices,those are:
#
# 1)'PMO - US'
#
# 2)'South Africa Field Office'
#
# 3)'Haiti Field Office'
#
# 4)'Ethiopia Field Offic

# %% [markdown]
# ###### Fullfill Via:
# From RDC(Regional Distribution Center): A distribution center that distributes to provincial (state) users with strong radiation capacity and inventory preparation. This kind of distribution center has a large distribution scale.
#
# Direct drop: Direct drop-shipping is where the retailer asks their suppliers or wholesalers to package and deliver orders directly to customers on their behalf.

# %% [markdown]
# ###### Vendor INCO Term:
# https://www.approvedforwarders.com/understanding-5-common-incoterms/#:~:text=Incoterms%20are%20a%20set%20of%20rules%20established%20by,Incoterms%20can%20reduce%20confusion%20between%20buyers%20and%20sellers.
#
# Incoterms specify who is responsible for paying for and managing the shipment, insurance, documentation, customs clearance, and other logistical activities.
# Incoterms:
#
# EXW (Ex Works)
#
# FCA (Free Carrier)
#
# CPT (Carriage Paid To)
#
# CIP (Carriage and Insurance Paid To)
#
# DAP (Delivered at Place)
#
# DDP (Delivered Duty Paid)
#
# CIF(Cost,Insurance And Freight)

# %% [markdown]
# ###### Shipment:
# Means of transport.

# %% [markdown]
# ###### PQ First Sent to Client Date:
# On which date the Performance Qualification is sent to client.
#
# We have information as Pre PQ process and dates.

# %% [markdown]
# ###### PO Sent to Vendor Date:
# On which date the Purchase Order sent to Vendor.

# %% [markdown]
# ###### Scheduled Delivery Date:
# The deivery will be delivered on that particular date.

# %% [markdown]
# ###### Delivered to Client Date:
# The date on which the product had delivered to client.

# %% [markdown]
# ###### Delivery Recorded Date:
# On which date the delivery happened is recorded.

# %% [markdown]
# ###### Product Group:
# Group of that particular product.

# %% [markdown]
# ###### Sub Classification:
# The classification of the product ccording to its use.

# %% [markdown]
# ###### Vendor:
# A company or a person offering for sale.(Trader)

# %% [markdown]
# ###### Item Description:
# Description about that item.

# %% [markdown]
# ###### Molecule/ Test type:
# Type of the molecule used in that Pharmaceutical product.

# %% [markdown]
# ###### Dosage:
# Quantity of the drug.

# %% [markdown]
# ###### Dosage Form:
# In which form that drug appears.Ex:- Tablet, Capsule, Injection etc.

# %% [markdown]
# ###### Manufacturing Site:
# A location where a Manufaturing operation is conducted.

# %% [markdown]
# ###### First line Designation:
# Attiribute to check the designation is first line or not.

# %% [markdown]
# ###### Weight (Kilograms):
# Weight of that particular packed product.

# %% [markdown]
# ###### Freight Cost:
# Freight costs are also known as freight charges or freight rates i.e the amount paid to a carrier company for the transportation of goods from the point of origin to an agreed location.

# %%
df.head(1)
# Out:
#    ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0   1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
#
#   Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 0   PMO - US  Direct Drop              EXW           Air
#
#   PQ First Sent to Client Date PO Sent to Vendor Date Scheduled Delivery Date  \
# 0               Pre-PQ Process      Date Not Captured                2-Jun-06
#
#   Delivered to Client Date Delivery Recorded Date Product Group  \
# 0                 2-Jun-06               2-Jun-06          HRDT
#
#   Sub Classification                       Vendor  \
# 0           HIV test  RANBAXY Fine Chemicals LTD.
#
#                                     Item Description  \
# 0  HIV, Reveal G3 Rapid HIV-1 Antibody Test, 30 T...
#
#                          Molecule/Test Type   Brand Dosage Dosage Form  \
# 0  HIV, Reveal G3 Rapid HIV-1 Antibody Test  Reveal    NaN    Test kit
#
#    Unit of Measure (Per Pack)  Line Item Quantity  Line Item Value  \
# 0                          30                  19            551.0
#
#    Pack Price  Unit Price          Manufacturing Site First Line Designation  \
# 0        29.0        0.97  Ranbaxy Fine Chemicals LTD                    Yes
#
#   Weight (Kilograms) Freight Cost (USD)  Line Item Insurance (USD)
# 0                 13             780.34                        NaN

# %% [markdown]
# ### Renaming the columns

# %%
df.rename(columns={'PQ #':'Performance Qualification'},inplace=True)

# %%
df.rename(columns={'PO / SO #':'Purchase(or)Shipping Order'},inplace=True)

# %%
df.rename(columns={'ASN/DN #':'Advanced Shipment Notice'},inplace=True)

# %%
df.head(1)
# Out:
#    ID Project Code Performance Qualification Purchase(or)Shipping Order  \
# 0   1   100-CI-T01            Pre-PQ Process                     SCMS-4
#
#   Advanced Shipment Notice        Country Managed By  Fulfill Via  \
# 0                    ASN-8  Côte d'Ivoire   PMO - US  Direct Drop
#
#   Vendor INCO Term Shipment Mode PQ First Sent to Client Date  \
# 0              EXW           Air               Pre-PQ Process
#
#   PO Sent to Vendor Date Scheduled Delivery Date Delivered to Client Date  \
# 0      Date Not Captured                2-Jun-06                 2-Jun-06
#
#   Delivery Recorded Date Product Group Sub Classification  \
# 0               2-Jun-06          HRDT           HIV test
#
#                         Vendor  \
# 0  RANBAXY Fine Chemicals LTD.
#
#                                     Item Description  \
# 0  HIV, Reveal G3 Rapid HIV-1 Antibody Test, 30 T...
#
#                          Molecule/Test Type   Brand Dosage Dosage Form  \
# 0  HIV, Reveal G3 Rapid HIV-1 Antibody Test  Reveal    NaN    Test kit
#
#    Unit of Measure (Per Pack)  Line Item Quantity  Line Item Value  \
# 0                          30                  19            551.0
#
#    Pack Price  Unit Price          Manufacturing Site First Line Designation  \
# 0        29.0        0.97  Ranbaxy Fine Chemicals LTD                    Yes
#
#   Weight (Kilograms) Freight Cost (USD)  Line Item Insurance (USD)
# 0                 13             780.34                        NaN

# %% [markdown]
# ### Numerical Features

# %%
num_feat=df.select_dtypes(include='number')
print('The Numerical Features of the data are:','\n',num_feat.columns)
# Out:
# The Numerical Features of the data are:
#  Index(['ID', 'Unit of Measure (Per Pack)', 'Line Item Quantity',
#        'Line Item Value', 'Pack Price', 'Unit Price',
#        'Line Item Insurance (USD)'],
#       dtype='object')

# %% [markdown]
# ## Handling Missing Values

# %%
df.isnull().sum()
# Out:
# ID                                 0
# Project Code                       0
# Performance Qualification          0
# Purchase(or)Shipping Order         0
# Advanced Shipment Notice           0
# Country                            0
# Managed By                         0
# Fulfill Via                        0
# Vendor INCO Term                   0
# Shipment Mode                    360
# PQ First Sent to Client Date       0
# PO Sent to Vendor Date             0
# Scheduled Delivery Date            0
# Delivered to Client Date           0
# Delivery Recorded Date             0
# Product Group                      0
# Sub Classification                 0
# Vendor                             0
# Item Description                   0
# Molecule/Test Type                 0
# Brand                              0
# Dosage                          1736
# Dosage Form                        0
# Unit of Measure (Per Pack)         0
# Line Item Quantity                 0
# Line Item Value                    0
# Pack Price                         0
# Unit Price                         0
# Manufacturing Site                 0
# First Line Designation             0
# Weight (Kilograms)                 0
# Freight Cost (USD)                 0
# Line Item Insurance (USD)        287
# dtype: int64

# %% [markdown]
# ### Visualizing the Null values

# %%
sns.heatmap(df.isnull(), yticklabels=False);

# %% [markdown]
# ###### Observation:
# Here we can see that null values are present in the columns Shipment Mode, Dosage and Line Insurance(USD).

# %% [markdown]
# ### Handling Null values in "Doasge" category.

# %%
df1=df[df['Dosage'].isnull()]
df1
# Out:
#           ID Project Code Performance Qualification  \
# 0          1   100-CI-T01            Pre-PQ Process
# 2          4   100-CI-T01            Pre-PQ Process
# 11        61   110-ZM-T01            Pre-PQ Process
# 12        62   102-NG-T01            Pre-PQ Process
# 14        65   106-HT-T01            Pre-PQ Process
# ...      ...          ...                       ...
# 8901   85082   102-SD-T30                  FPQ-3812
# 9564   85865   110-ZM-T30                  FPQ-9515
# 9734   86064   101-KE-T30                 FPQ-13822
# 9863   86258   102-SD-T30                  FPQ-3812
# 10055  86457   109-TZ-T30                  FPQ-9275
#
#       Purchase(or)Shipping Order Advanced Shipment Notice        Country  \
# 0                         SCMS-4                    ASN-8  Côte d'Ivoire
# 2                        SCMS-20                   ASN-14  Côte d'Ivoire
# 11                      SCMS-226                  ASN-137         Zambia
# 12                      SCMS-230                  ASN-144        Nigeria
# 14                      SCMS-274                  ASN-162          Haiti
# ...                          ...                      ...            ...
# 8901                    SO-34550                  DN-1624          Sudan
# 9564                    SO-41950                  DN-2681         Zambia
# 9734                    SO-48080                  DN-3591          Kenya
# 9863                    SO-34550                  DN-1624          Sudan
# 10055                   SO-41460                  DN-2583       Tanzania
#
#       Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 0       PMO - US  Direct Drop              EXW           Air
# 2       PMO - US  Direct Drop              FCA           Air
# 11      PMO - US  Direct Drop              EXW           Air
# 12      PMO - US  Direct Drop              EXW           Air
# 14      PMO - US  Direct Drop              EXW           Air
# ...          ...          ...              ...           ...
# 8901    PMO - US     From RDC   N/A - From RDC           Air
# 9564    PMO - US     From RDC   N/A - From RDC           Air
# 9734    PMO - US     From RDC   N/A - From RDC         Truck
# 9863    PMO - US     From RDC   N/A - From RDC           Air
# 10055   PMO - US     From RDC   N/A - From RDC           Air
#
#       PQ First Sent to Client Date PO Sent to Vendor Date  \
# 0                   Pre-PQ Process      Date Not Captured
# 2                   Pre-PQ Process      Date Not Captured
# 11                  Pre-PQ Process      Date Not Captured
# 12                  Pre-PQ Process      Date Not Captured
# 14                  Pre-PQ Process      Date Not Captured
# ...                            ...                    ...
# 8901                        6/3/09         N/A - From RDC
# 9564                       4/10/12         N/A - From RDC
# 9734                       2/27/14         N/A - From RDC
# 9863                        6/3/09         N/A - From RDC
# 10055                       2/2/12         N/A - From RDC
#
#       Scheduled Delivery Date Delivered to Client Date Delivery Recorded Date  \
# 0                    2-Jun-06                 2-Jun-06               2-Jun-06
# 2                   27-Aug-06                27-Aug-06              27-Aug-06
# 11                   8-Jan-07                 8-Jan-07               8-Jan-07
# 12                  10-Jan-07                10-Jan-07              10-Jan-07
# 14                  18-Jan-07                18-Jan-07              18-Jan-07
# ...                       ...                      ...                    ...
# 8901                30-Nov-09                22-Nov-09              22-Nov-09
# 9564                 2-Jul-12                 7-Jun-12               7-Jun-12
# 9734                 3-Apr-14                11-Mar-14               9-Jul-14
# 9863                30-Nov-09                22-Nov-09              22-Nov-09
# 10055               30-Mar-12                 7-Mar-12               7-Mar-12
#
#       Product Group Sub Classification                       Vendor  \
# 0              HRDT           HIV test  RANBAXY Fine Chemicals LTD.
# 2              HRDT           HIV test         Abbott GmbH & Co. KG
# 11             HRDT           HIV test         Trinity Biotech, Plc
# 12             HRDT           HIV test              EY Laboratories
# 14             HRDT           HIV test         Abbott GmbH & Co. KG
# ...             ...                ...                          ...
# 8901           HRDT           HIV test                SCMS from RDC
# 9564           HRDT           HIV test                SCMS from RDC
# 9734           HRDT           HIV test                SCMS from RDC
# 9863           HRDT           HIV test                SCMS from RDC
# 10055          HRDT           HIV test                SCMS from RDC
#
#                                         Item Description  \
# 0      HIV, Reveal G3 Rapid HIV-1 Antibody Test, 30 T...
# 2         HIV 1/2, Determine Complete HIV Kit, 100 Tests
# 11                   HIV 1/2, Uni-Gold HIV Kit, 20 Tests
# 12           HIV 1/2, InstantChek HIV 1+2 Kit, 100 Tests
# 14        HIV 1/2, Determine Complete HIV Kit, 100 Tests
# ...                                                  ...
# 8901      HIV 1/2, Determine Complete HIV Kit, 100 Tests
# 9564      HIV 1/2, Determine Complete HIV Kit, 100 Tests
# 9734   HIV 1/2/O, First Response HIV 1-2.0, v.3.0 Car...
# 9863   HIV 1/2, Bioline 3.0 Kit, Lancets, Capillary p...
# 10055                HIV 1/2, Uni-Gold HIV Kit, 20 Tests
#
#                                       Molecule/Test Type           Brand  \
# 0               HIV, Reveal G3 Rapid HIV-1 Antibody Test          Reveal
# 2                    HIV 1/2, Determine Complete HIV Kit       Determine
# 11                             HIV 1/2, Uni-Gold HIV Kit        Uni-Gold
# 12                      HIV 1/2, InstantChek HIV 1+2 Kit     InstantCHEK
# 14                   HIV 1/2, Determine Complete HIV Kit       Determine
# ...                                                  ...             ...
# 8901                 HIV 1/2, Determine Complete HIV Kit       Determine
# 9564                 HIV 1/2, Determine Complete HIV Kit       Determine
# 9734   HIV 1/2/O, First Response HIV 1-2.0, v.3.0 Car...  First Response
# 9863   HIV 1/2, Bioline 3.0 Kit, Lancets, Capillary p...         Bioline
# 10055                          HIV 1/2, Uni-Gold HIV Kit        Uni-Gold
#
#       Dosage Dosage Form  Unit of Measure (Per Pack)  Line Item Quantity  \
# 0        NaN    Test kit                          30                  19
# 2        NaN    Test kit                         100                 500
# 11       NaN    Test kit                          20                2500
# 12       NaN    Test kit                         100                  10
# 14       NaN    Test kit                         100                 750
# ...      ...         ...                         ...                 ...
# 8901     NaN    Test kit                         100                 350
# 9564     NaN    Test kit                         100                5996
# 9734     NaN    Test kit                          30                2429
# 9863     NaN    Test kit                          25                 100
# 10055    NaN    Test kit                          20                5000
#
#        Line Item Value  Pack Price  Unit Price             Manufacturing Site  \
# 0                551.0        29.0        0.97     Ranbaxy Fine Chemicals LTD
# 2              40000.0        80.0        0.80  ABBVIE GmbH & Co.KG Wiesbaden
# 11            100000.0        40.0        2.00           Trinity Biotech, Plc
# 12               850.0        85.0        0.85           EY Laboratories, USA
# 14             60000.0        80.0        0.80  ABBVIE GmbH & Co.KG Wiesbaden
# ...                ...         ...         ...                            ...
# 8901           28000.0        80.0        0.80                Inverness Japan
# 9564          479680.0        80.0        0.80        Alere Medical Co., Ltd.
# 9734               0.0         0.0        0.00   Premier Med. Corp Ltd. India
# 9863            2000.0        20.0        0.80    Standard Diagnostics, Korea
# 10055         160000.0        32.0        1.60           Trinity Biotech, Plc
#
#       First Line Designation          Weight (Kilograms)  \
# 0                        Yes                          13
# 2                        Yes                         171
# 11                       Yes                         853
# 12                       Yes  Weight Captured Separately
# 14                       Yes                         256
# ...                      ...                         ...
# 8901                      No     See DN-1624 (ID#:82856)
# 9564                     Yes                        1363
# 9734                     Yes  Weight Captured Separately
# 9863                      No     See DN-1624 (ID#:82856)
# 10055                    Yes                        1578
#
#             Freight Cost (USD)  Line Item Insurance (USD)
# 0                       780.34                        NaN
# 2                      1653.78                        NaN
# 11                    13569.49                        NaN
# 12         Invoiced Separately                        NaN
# 14                     1760.32                        NaN
# ...                        ...                        ...
# 8901   See DN-1624 (ID#:82856)                      54.88
# 9564                   22171.8                     672.51
# 9734       Invoiced Separately                       0.00
# 9863   See DN-1624 (ID#:82856)                       3.92
# 10055                     8925                     224.32
#
# [1736 rows x 33 columns]

# %% [markdown]
# ##### Attribute 'Dosage' has 1736 missing values

# %%
df1.shape
# Out:
# (1736, 33)

# %%
df['Product Group'].value_counts()
# Out:
# ARV     8550
# HRDT    1728
# ANTM      22
# ACT       16
# MRDT       8
# Name: Product Group, dtype: int64

# %%
new_df=df[df['Product Group']=='HRDT']
new_df
# Out:
#           ID Project Code Performance Qualification  \
# 0          1   100-CI-T01            Pre-PQ Process
# 2          4   100-CI-T01            Pre-PQ Process
# 11        61   110-ZM-T01            Pre-PQ Process
# 12        62   102-NG-T01            Pre-PQ Process
# 14        65   106-HT-T01            Pre-PQ Process
# ...      ...          ...                       ...
# 8901   85082   102-SD-T30                  FPQ-3812
# 9564   85865   110-ZM-T30                  FPQ-9515
# 9734   86064   101-KE-T30                 FPQ-13822
# 9863   86258   102-SD-T30                  FPQ-3812
# 10055  86457   109-TZ-T30                  FPQ-9275
#
#       Purchase(or)Shipping Order Advanced Shipment Notice        Country  \
# 0                         SCMS-4                    ASN-8  Côte d'Ivoire
# 2                        SCMS-20                   ASN-14  Côte d'Ivoire
# 11                      SCMS-226                  ASN-137         Zambia
# 12                      SCMS-230                  ASN-144        Nigeria
# 14                      SCMS-274                  ASN-162          Haiti
# ...                          ...                      ...            ...
# 8901                    SO-34550                  DN-1624          Sudan
# 9564                    SO-41950                  DN-2681         Zambia
# 9734                    SO-48080                  DN-3591          Kenya
# 9863                    SO-34550                  DN-1624          Sudan
# 10055                   SO-41460                  DN-2583       Tanzania
#
#       Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 0       PMO - US  Direct Drop              EXW           Air
# 2       PMO - US  Direct Drop              FCA           Air
# 11      PMO - US  Direct Drop              EXW           Air
# 12      PMO - US  Direct Drop              EXW           Air
# 14      PMO - US  Direct Drop              EXW           Air
# ...          ...          ...              ...           ...
# 8901    PMO - US     From RDC   N/A - From RDC           Air
# 9564    PMO - US     From RDC   N/A - From RDC           Air
# 9734    PMO - US     From RDC   N/A - From RDC         Truck
# 9863    PMO - US     From RDC   N/A - From RDC           Air
# 10055   PMO - US     From RDC   N/A - From RDC           Air
#
#       PQ First Sent to Client Date PO Sent to Vendor Date  \
# 0                   Pre-PQ Process      Date Not Captured
# 2                   Pre-PQ Process      Date Not Captured
# 11                  Pre-PQ Process      Date Not Captured
# 12                  Pre-PQ Process      Date Not Captured
# 14                  Pre-PQ Process      Date Not Captured
# ...                            ...                    ...
# 8901                        6/3/09         N/A - From RDC
# 9564                       4/10/12         N/A - From RDC
# 9734                       2/27/14         N/A - From RDC
# 9863                        6/3/09         N/A - From RDC
# 10055                       2/2/12         N/A - From RDC
#
#       Scheduled Delivery Date Delivered to Client Date Delivery Recorded Date  \
# 0                    2-Jun-06                 2-Jun-06               2-Jun-06
# 2                   27-Aug-06                27-Aug-06              27-Aug-06
# 11                   8-Jan-07                 8-Jan-07               8-Jan-07
# 12                  10-Jan-07                10-Jan-07              10-Jan-07
# 14                  18-Jan-07                18-Jan-07              18-Jan-07
# ...                       ...                      ...                    ...
# 8901                30-Nov-09                22-Nov-09              22-Nov-09
# 9564                 2-Jul-12                 7-Jun-12               7-Jun-12
# 9734                 3-Apr-14                11-Mar-14               9-Jul-14
# 9863                30-Nov-09                22-Nov-09              22-Nov-09
# 10055               30-Mar-12                 7-Mar-12               7-Mar-12
#
#       Product Group Sub Classification                       Vendor  \
# 0              HRDT           HIV test  RANBAXY Fine Chemicals LTD.
# 2              HRDT           HIV test         Abbott GmbH & Co. KG
# 11             HRDT           HIV test         Trinity Biotech, Plc
# 12             HRDT           HIV test              EY Laboratories
# 14             HRDT           HIV test         Abbott GmbH & Co. KG
# ...             ...                ...                          ...
# 8901           HRDT           HIV test                SCMS from RDC
# 9564           HRDT           HIV test                SCMS from RDC
# 9734           HRDT           HIV test                SCMS from RDC
# 9863           HRDT           HIV test                SCMS from RDC
# 10055          HRDT           HIV test                SCMS from RDC
#
#                                         Item Description  \
# 0      HIV, Reveal G3 Rapid HIV-1 Antibody Test, 30 T...
# 2         HIV 1/2, Determine Complete HIV Kit, 100 Tests
# 11                   HIV 1/2, Uni-Gold HIV Kit, 20 Tests
# 12           HIV 1/2, InstantChek HIV 1+2 Kit, 100 Tests
# 14        HIV 1/2, Determine Complete HIV Kit, 100 Tests
# ...                                                  ...
# 8901      HIV 1/2, Determine Complete HIV Kit, 100 Tests
# 9564      HIV 1/2, Determine Complete HIV Kit, 100 Tests
# 9734   HIV 1/2/O, First Response HIV 1-2.0, v.3.0 Car...
# 9863   HIV 1/2, Bioline 3.0 Kit, Lancets, Capillary p...
# 10055                HIV 1/2, Uni-Gold HIV Kit, 20 Tests
#
#                                       Molecule/Test Type           Brand  \
# 0               HIV, Reveal G3 Rapid HIV-1 Antibody Test          Reveal
# 2                    HIV 1/2, Determine Complete HIV Kit       Determine
# 11                             HIV 1/2, Uni-Gold HIV Kit        Uni-Gold
# 12                      HIV 1/2, InstantChek HIV 1+2 Kit     InstantCHEK
# 14                   HIV 1/2, Determine Complete HIV Kit       Determine
# ...                                                  ...             ...
# 8901                 HIV 1/2, Determine Complete HIV Kit       Determine
# 9564                 HIV 1/2, Determine Complete HIV Kit       Determine
# 9734   HIV 1/2/O, First Response HIV 1-2.0, v.3.0 Car...  First Response
# 9863   HIV 1/2, Bioline 3.0 Kit, Lancets, Capillary p...         Bioline
# 10055                          HIV 1/2, Uni-Gold HIV Kit        Uni-Gold
#
#       Dosage Dosage Form  Unit of Measure (Per Pack)  Line Item Quantity  \
# 0        NaN    Test kit                          30                  19
# 2        NaN    Test kit                         100                 500
# 11       NaN    Test kit                          20                2500
# 12       NaN    Test kit                         100                  10
# 14       NaN    Test kit                         100                 750
# ...      ...         ...                         ...                 ...
# 8901     NaN    Test kit                         100                 350
# 9564     NaN    Test kit                         100                5996
# 9734     NaN    Test kit                          30                2429
# 9863     NaN    Test kit                          25                 100
# 10055    NaN    Test kit                          20                5000
#
#        Line Item Value  Pack Price  Unit Price             Manufacturing Site  \
# 0                551.0        29.0        0.97     Ranbaxy Fine Chemicals LTD
# 2              40000.0        80.0        0.80  ABBVIE GmbH & Co.KG Wiesbaden
# 11            100000.0        40.0        2.00           Trinity Biotech, Plc
# 12               850.0        85.0        0.85           EY Laboratories, USA
# 14             60000.0        80.0        0.80  ABBVIE GmbH & Co.KG Wiesbaden
# ...                ...         ...         ...                            ...
# 8901           28000.0        80.0        0.80                Inverness Japan
# 9564          479680.0        80.0        0.80        Alere Medical Co., Ltd.
# 9734               0.0         0.0        0.00   Premier Med. Corp Ltd. India
# 9863            2000.0        20.0        0.80    Standard Diagnostics, Korea
# 10055         160000.0        32.0        1.60           Trinity Biotech, Plc
#
#       First Line Designation          Weight (Kilograms)  \
# 0                        Yes                          13
# 2                        Yes                         171
# 11                       Yes                         853
# 12                       Yes  Weight Captured Separately
# 14                       Yes                         256
# ...                      ...                         ...
# 8901                      No     See DN-1624 (ID#:82856)
# 9564                     Yes                        1363
# 9734                     Yes  Weight Captured Separately
# 9863                      No     See DN-1624 (ID#:82856)
# 10055                    Yes                        1578
#
#             Freight Cost (USD)  Line Item Insurance (USD)
# 0                       780.34                        NaN
# 2                      1653.78                        NaN
# 11                    13569.49                        NaN
# 12         Invoiced Separately                        NaN
# 14                     1760.32                        NaN
# ...                        ...                        ...
# 8901   See DN-1624 (ID#:82856)                      54.88
# 9564                   22171.8                     672.51
# 9734       Invoiced Separately                       0.00
# 9863   See DN-1624 (ID#:82856)                       3.92
# 10055                     8925                     224.32
#
# [1728 rows x 33 columns]

# %%
new_df['Dosage Form'].value_counts()
# Out:
# Test kit                1567
# Test kit - Ancillary     161
# Name: Dosage Form, dtype: int64

# %% [markdown]
# #### Observation:
# Here we can observe that the null values in 'Dosage' column are given for entire 'Test kit' and 'Test kit-Ancellary' categories in 'Dosage form' column which are all belonging to HRDT and MRDT 'Product groups' and we cannot describe the Dosage weight for Test kits because the 'Test Kit' actually means that collection of medicines for First Aid. We can describe the Dosage weight for it as 'No weight Measurement'.

# %%
df['Dosage']=df['Dosage'].fillna(df['Dosage'].isnull().values=='No Weight Measurement')

# %% [markdown]
# ### Handling Null values in 'shipment Mode'

# %% [markdown]
# #### Data had 360 null values in the column 'Shipment Mode' that can filled with Highly repeated value(i.e Mode)

# %%
df['Shipment Mode'].value_counts()
# Out:
# Air            6113
# Truck          2830
# Air Charter     650
# Ocean           371
# Name: Shipment Mode, dtype: int64

# %% [markdown]
# ##### Observation:
# Here we can see that the 'Air' shipment mode is high. Therefore we can replace the null values with this this category.

# %%
df['Shipment Mode']=df['Shipment Mode'].replace(np.nan,str(df['Shipment Mode'].mode()))

# %% [markdown]
# ### Handling Null values in "Line Insurance(USD)"

# %% [markdown]
# #### There are 287 null values in the'Line Item Insurance (USD)' column which is a numrical variable.

# %% [markdown]
# ##### Observation:
# The column 'Line Item Insurance (USD)' is a numerical variable,hence the null values can be replaced with the mean of all values in that column

# %%
df['Line Item Insurance (USD)']=df['Line Item Insurance (USD)'].fillna(df['Line Item Insurance (USD)'].mean())

# %% [markdown]
# #### Missing values - Cross check

# %%
df.isnull().sum()
# Out:
# ID                              0
# Project Code                    0
# Performance Qualification       0
# Purchase(or)Shipping Order      0
# Advanced Shipment Notice        0
# Country                         0
# Managed By                      0
# Fulfill Via                     0
# Vendor INCO Term                0
# Shipment Mode                   0
# PQ First Sent to Client Date    0
# PO Sent to Vendor Date          0
# Scheduled Delivery Date         0
# Delivered to Client Date        0
# Delivery Recorded Date          0
# Product Group                   0
# Sub Classification              0
# Vendor                          0
# Item Description                0
# Molecule/Test Type              0
# Brand                           0
# Dosage                          0
# Dosage Form                     0
# Unit of Measure (Per Pack)      0
# Line Item Quantity              0
# Line Item Value                 0
# Pack Price                      0
# Unit Price                      0
# Manufacturing Site              0
# First Line Designation          0
# Weight (Kilograms)              0
# Freight Cost (USD)              0
# Line Item Insurance (USD)       0
# dtype: int64

# %%
#Visualising again.
sns.heatmap(df.isnull(),yticklabels=False);

# %% [markdown]
# ### Duplicated records

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ###### Observation:
# There are no duplicate records in the given data

# %% [markdown]
# ## Outliers

# %%
df1=df.describe(percentiles=[0.01,0.05,0.1,0.25,0.5,0.75,0.90,0.95,0.99])
df1
# Out:
#                  ID  Unit of Measure (Per Pack)  Line Item Quantity  \
# count  10324.000000                10324.000000        10324.000000
# mean   51098.968229                   77.990895        18332.534870
# std    31944.332496                   76.579764        40035.302961
# min        1.000000                    1.000000            1.000000
# 1%      1078.230000                    1.000000            3.000000
# 5%      5151.200000                   20.000000           17.000000
# 10%    10547.300000                   30.000000           50.000000
# 25%    12795.750000                   30.000000          408.000000
# 50%    57540.500000                   60.000000         3000.000000
# 75%    83648.250000                   90.000000        17039.750000
# 90%    85541.700000                  180.000000        53267.000000
# 95%    86167.850000                  240.000000        90951.550000
# 99%    86651.770000                  300.000000       186888.780000
# max    86823.000000                 1000.000000       619999.000000
#
#        Line Item Value    Pack Price    Unit Price  Line Item Insurance (USD)
# count     1.032400e+04  10324.000000  10324.000000               10324.000000
# mean      1.576506e+05     21.910241      0.611701                 240.117626
# std       3.452921e+05     45.609223      3.275808                 493.188408
# min       0.000000e+00      0.000000      0.000000                   0.000000
# 1%        1.587680e+01      0.390000      0.010000                   0.020000
# 5%        1.925755e+02      1.900000      0.010000                   0.260000
# 10%       6.081200e+02      2.240000      0.040000                   0.880000
# 25%       4.314593e+03      4.120000      0.080000                   7.030000
# 50%       3.047147e+04      9.300000      0.160000                  52.940000
# 75%       1.664471e+05     23.592500      0.470000                 241.750000
# 90%       4.374878e+05     69.940000      0.890000                 669.052000
# 95%       7.028310e+05     80.000000      1.600000                1061.350000
# 99%       1.592935e+06    139.000000      5.000000                2419.030000
# max       5.951990e+06   1345.640000    238.650000                7708.440000

# %%
plt.figure(figsize=(10,5))
sns.boxplot('Unit of Measure (Per Pack)',data=df);

# %%
A=df['Unit of Measure (Per Pack)'].quantile(0.25)
B=df['Unit of Measure (Per Pack)'].quantile(0.75)

#Inter Quartile Range
IQR=B-A
print(IQR)
lower_limit=A-1.5*IQR
upper_limit=B+1.5*IQR
print(lower_limit,upper_limit)
# Out:
# 60.0
# -60.0 180.0

# %%
df['Unit of Measure (Per Pack)']=np.where(df['Unit of Measure (Per Pack)']>180,180,df['Unit of Measure (Per Pack)'])

# %%
sns.boxplot('Unit of Measure (Per Pack)',data=df);

# %%
sns.boxplot('Line Item Quantity',data=df);

# %%
A=df['Line Item Quantity'].quantile(0.25)
B=df['Line Item Quantity'].quantile(0.75)
IQR=B-A
print(IQR)
lower_limit=A-1.5*IQR
upper_limit=B+1.5*IQR
print(lower_limit,upper_limit)
# Out:
# 16631.75
# -24539.625 41987.375

# %%
df['Line Item Quantity']=np.where(df['Line Item Quantity']>41987,41987,df['Line Item Quantity'])

# %%
sns.boxplot('Line Item Quantity',data=df);

# %%
sns.boxplot('Line Item Value',data=df);

# %%
#Extreme Outliers for 'Line Item Value'
A=df['Line Item Value'].quantile(0.25)
B=df['Line Item Value'].quantile(0.75)
IQR=B-A
print(IQR)
lower_limit=A-1.5*IQR
upper_limit=B+1.5*IQR
print(lower_limit,upper_limit)
# Out:
# 162132.5475
# -238884.22874999998 409645.96124999993

# %%
df['Line Item Value']=np.where(df['Line Item Value']>409645,409645,df['Line Item Value'])

# %%
sns.boxplot('Line Item Value',data=df);

# %%
sns.boxplot('Pack Price',data=df);

# %%
A=df['Pack Price'].quantile(0.25)
B=df['Pack Price'].quantile(0.75)
IQR=B-A
print(IQR)
lower_limit=A-1.5*IQR
upper_limit=B+1.5*IQR
print(lower_limit,upper_limit)
# Out:
# 19.4725
# -25.08875 52.80125

# %%
df['Pack Price']=np.where(df['Pack Price']>52,52,df['Pack Price'])

# %%
sns.boxplot('Pack Price',data=df);

# %%
sns.boxplot('Unit Price',data=df);

# %%
A=df['Unit Price'].quantile(0.25)
B=df['Unit Price'].quantile(0.75)
IQR=B-A
print(IQR)
lower_limit=A-1.5*IQR
upper_limit=B+1.5*IQR
print(lower_limit,upper_limit)
# Out:
# 0.38999999999999996
# -0.505 1.055

# %%
df['Unit Price']=np.where(df['Unit Price']>1,1,df['Unit Price'])

# %%
sns.boxplot('Unit Price',data=df);

# %%
sns.boxplot('Line Item Insurance (USD)',data=df);

# %%
A=df['Line Item Insurance (USD)'].quantile(0.25)
B=df['Line Item Insurance (USD)'].quantile(0.75)
IQR=B-A
print(IQR)
lower_limit=A-1.5*IQR
upper_limit=B+1.5*IQR
print(lower_limit,upper_limit)
# Out:
# 234.72
# -345.05 593.8299999999999

# %%
df['Line Item Insurance (USD)']=np.where(df['Line Item Insurance (USD)']>621,621,df['Line Item Insurance (USD)'])

# %%
sns.boxplot('Line Item Insurance (USD)',data=df);

# %%
df.describe()
# Out:
#                  ID  Unit of Measure (Per Pack)  Line Item Quantity  \
# count  10324.000000                10324.000000        10324.000000
# mean   51098.968229                   69.297172        11163.128729
# std    31944.332496                   46.417603        14990.979423
# min        1.000000                    1.000000            1.000000
# 25%    12795.750000                   30.000000          408.000000
# 50%    57540.500000                   60.000000         3000.000000
# 75%    83648.250000                   90.000000        17039.750000
# max    86823.000000                  180.000000        41987.000000
#
#        Line Item Value    Pack Price    Unit Price  Line Item Insurance (USD)
# count     10324.000000  10324.000000  10324.000000               10324.000000
# mean     105691.099440     16.215625      0.315993                 163.749551
# std      139246.742744     16.190944      0.323232                 209.622698
# min           0.000000      0.000000      0.000000                   0.000000
# 25%        4314.592500      4.120000      0.080000                   7.030000
# 50%       30471.465000      9.300000      0.160000                  52.940000
# 75%      166447.140000     23.592500      0.470000                 241.750000
# max      409645.000000     52.000000      1.000000                 621.000000

# %%
df.head()
# Out:
#    ID Project Code Performance Qualification Purchase(or)Shipping Order  \
# 0   1   100-CI-T01            Pre-PQ Process                     SCMS-4
# 1   3   108-VN-T01            Pre-PQ Process                    SCMS-13
# 2   4   100-CI-T01            Pre-PQ Process                    SCMS-20
# 3  15   108-VN-T01            Pre-PQ Process                    SCMS-78
# 4  16   108-VN-T01            Pre-PQ Process                    SCMS-81
#
#   Advanced Shipment Notice        Country Managed By  Fulfill Via  \
# 0                    ASN-8  Côte d'Ivoire   PMO - US  Direct Drop
# 1                   ASN-85        Vietnam   PMO - US  Direct Drop
# 2                   ASN-14  Côte d'Ivoire   PMO - US  Direct Drop
# 3                   ASN-50        Vietnam   PMO - US  Direct Drop
# 4                   ASN-55        Vietnam   PMO - US  Direct Drop
#
#   Vendor INCO Term Shipment Mode PQ First Sent to Client Date  \
# 0              EXW           Air               Pre-PQ Process
# 1              EXW           Air               Pre-PQ Process
# 2              FCA           Air               Pre-PQ Process
# 3              EXW           Air               Pre-PQ Process
# 4              EXW           Air               Pre-PQ Process
#
#   PO Sent to Vendor Date Scheduled Delivery Date Delivered to Client Date  \
# 0      Date Not Captured                2-Jun-06                 2-Jun-06
# 1      Date Not Captured               14-Nov-06                14-Nov-06
# 2      Date Not Captured               27-Aug-06                27-Aug-06
# 3      Date Not Captured                1-Sep-06                 1-Sep-06
# 4      Date Not Captured               11-Aug-06                11-Aug-06
#
#   Delivery Recorded Date Product Group Sub Classification  \
# 0               2-Jun-06          HRDT           HIV test
# 1              14-Nov-06           ARV          Pediatric
# 2              27-Aug-06          HRDT           HIV test
# 3               1-Sep-06           ARV              Adult
# 4              11-Aug-06           ARV              Adult
#
#                                               Vendor  \
# 0                        RANBAXY Fine Chemicals LTD.
# 1                           Aurobindo Pharma Limited
# 2                               Abbott GmbH & Co. KG
# 3  SUN PHARMACEUTICAL INDUSTRIES LTD (RANBAXY LAB...
# 4                           Aurobindo Pharma Limited
#
#                                     Item Description  \
# 0  HIV, Reveal G3 Rapid HIV-1 Antibody Test, 30 T...
# 1  Nevirapine 10mg/ml, oral suspension, Bottle, 2...
# 2     HIV 1/2, Determine Complete HIV Kit, 100 Tests
# 3                 Lamivudine 150mg, tablets, 60 Tabs
# 4                  Stavudine 30mg, capsules, 60 Caps
#
#                          Molecule/Test Type      Brand   Dosage  \
# 0  HIV, Reveal G3 Rapid HIV-1 Antibody Test     Reveal    False
# 1                                Nevirapine    Generic  10mg/ml
# 2       HIV 1/2, Determine Complete HIV Kit  Determine    False
# 3                                Lamivudine    Generic    150mg
# 4                                 Stavudine    Generic     30mg
#
#        Dosage Form  Unit of Measure (Per Pack)  Line Item Quantity  \
# 0         Test kit                          30                  19
# 1  Oral suspension                         180                1000
# 2         Test kit                         100                 500
# 3           Tablet                          60               31920
# 4          Capsule                          60               38000
#
#    Line Item Value  Pack Price  Unit Price             Manufacturing Site  \
# 0            551.0       29.00        0.97     Ranbaxy Fine Chemicals LTD
# 1           6200.0        6.20        0.03      Aurobindo Unit III, India
# 2          40000.0       52.00        0.80  ABBVIE GmbH & Co.KG Wiesbaden
# 3         127360.8        3.99        0.07  Ranbaxy, Paonta Shahib, India
# 4         121600.0        3.20        0.05      Aurobindo Unit III, India
#
#   First Line Designation Weight (Kilograms) Freight Cost (USD)  \
# 0                    Yes                 13             780.34
# 1                    Yes                358             4521.5
# 2                    Yes                171            1653.78
# 3                    Yes               1855           16007.06
# 4                    Yes               7590           45450.08
#
#    Line Item Insurance (USD)
# 0                 240.117626
# 1                 240.117626
# 2                 240.117626
# 3                 240.117626
# 4                 240.117626

# %% [markdown]
# ## Correlation Matrix

# %%
corr=df.corr()
sns.heatmap(corr,annot=True);

# %% [markdown]
# ###### Observation:
# Here we can observe that the columns "Line Item Insurance(USD)", "Line Item Value" and "Line Item Quantity" are highly correlated with each other,so any one of them is considered.

# %% [markdown]
# ##### Line Item:
# Line Item is a code taht is given to each item with respect to the coveyor belt or the machine it is created on.

# %% [markdown]
# ##### Line Item Quantity:
# Line item Quantity is supposed to be the number of items created in that machine.

# %%
df.drop(['Line Item Insurance (USD)' ,'Line Item Quantity'],axis=1,inplace=True)

# %%
#VIsualise the data and check whther the columns are present or not.
df.head(2)
# Out:
#    ID Project Code Performance Qualification Purchase(or)Shipping Order  \
# 0   1   100-CI-T01            Pre-PQ Process                     SCMS-4
# 1   3   108-VN-T01            Pre-PQ Process                    SCMS-13
#
#   Advanced Shipment Notice        Country Managed By  Fulfill Via  \
# 0                    ASN-8  Côte d'Ivoire   PMO - US  Direct Drop
# 1                   ASN-85        Vietnam   PMO - US  Direct Drop
#
#   Vendor INCO Term Shipment Mode PQ First Sent to Client Date  \
# 0              EXW           Air               Pre-PQ Process
# 1              EXW           Air               Pre-PQ Process
#
#   PO Sent to Vendor Date Scheduled Delivery Date Delivered to Client Date  \
# 0      Date Not Captured                2-Jun-06                 2-Jun-06
# 1      Date Not Captured               14-Nov-06                14-Nov-06
#
#   Delivery Recorded Date Product Group Sub Classification  \
# 0               2-Jun-06          HRDT           HIV test
# 1              14-Nov-06           ARV          Pediatric
#
#                         Vendor  \
# 0  RANBAXY Fine Chemicals LTD.
# 1     Aurobindo Pharma Limited
#
#                                     Item Description  \
# 0  HIV, Reveal G3 Rapid HIV-1 Antibody Test, 30 T...
# 1  Nevirapine 10mg/ml, oral suspension, Bottle, 2...
#
#                          Molecule/Test Type    Brand   Dosage  \
# 0  HIV, Reveal G3 Rapid HIV-1 Antibody Test   Reveal    False
# 1                                Nevirapine  Generic  10mg/ml
#
#        Dosage Form  Unit of Measure (Per Pack)  Line Item Value  Pack Price  \
# 0         Test kit                          30            551.0        29.0
# 1  Oral suspension                         180           6200.0         6.2
#
#    Unit Price          Manufacturing Site First Line Designation  \
# 0        0.97  Ranbaxy Fine Chemicals LTD                    Yes
# 1        0.03   Aurobindo Unit III, India                    Yes
#
#   Weight (Kilograms) Freight Cost (USD)
# 0                 13             780.34
# 1                358             4521.5

# %% [markdown]
# ###### Observation:
# Here we can also see that the columns 'Delivered to Client Date' and 'Delivered Recorded Date' represents the dates which are same,so any one of the both columns is excluded .

# %%
df.drop('Delivery Recorded Date',axis=1,inplace=True)

# %%
df.head()
# Out:
#    ID Project Code Performance Qualification Purchase(or)Shipping Order  \
# 0   1   100-CI-T01            Pre-PQ Process                     SCMS-4
# 1   3   108-VN-T01            Pre-PQ Process                    SCMS-13
# 2   4   100-CI-T01            Pre-PQ Process                    SCMS-20
# 3  15   108-VN-T01            Pre-PQ Process                    SCMS-78
# 4  16   108-VN-T01            Pre-PQ Process                    SCMS-81
#
#   Advanced Shipment Notice        Country Managed By  Fulfill Via  \
# 0                    ASN-8  Côte d'Ivoire   PMO - US  Direct Drop
# 1                   ASN-85        Vietnam   PMO - US  Direct Drop
# 2                   ASN-14  Côte d'Ivoire   PMO - US  Direct Drop
# 3                   ASN-50        Vietnam   PMO - US  Direct Drop
# 4                   ASN-55        Vietnam   PMO - US  Direct Drop
#
#   Vendor INCO Term Shipment Mode PQ First Sent to Client Date  \
# 0              EXW           Air               Pre-PQ Process
# 1              EXW           Air               Pre-PQ Process
# 2              FCA           Air               Pre-PQ Process
# 3              EXW           Air               Pre-PQ Process
# 4              EXW           Air               Pre-PQ Process
#
#   PO Sent to Vendor Date Scheduled Delivery Date Delivered to Client Date  \
# 0      Date Not Captured                2-Jun-06                 2-Jun-06
# 1      Date Not Captured               14-Nov-06                14-Nov-06
# 2      Date Not Captured               27-Aug-06                27-Aug-06
# 3      Date Not Captured                1-Sep-06                 1-Sep-06
# 4      Date Not Captured               11-Aug-06                11-Aug-06
#
#   Product Group Sub Classification  \
# 0          HRDT           HIV test
# 1           ARV          Pediatric
# 2          HRDT           HIV test
# 3           ARV              Adult
# 4           ARV              Adult
#
#                                               Vendor  \
# 0                        RANBAXY Fine Chemicals LTD.
# 1                           Aurobindo Pharma Limited
# 2                               Abbott GmbH & Co. KG
# 3  SUN PHARMACEUTICAL INDUSTRIES LTD (RANBAXY LAB...
# 4                           Aurobindo Pharma Limited
#
#                                     Item Description  \
# 0  HIV, Reveal G3 Rapid HIV-1 Antibody Test, 30 T...
# 1  Nevirapine 10mg/ml, oral suspension, Bottle, 2...
# 2     HIV 1/2, Determine Complete HIV Kit, 100 Tests
# 3                 Lamivudine 150mg, tablets, 60 Tabs
# 4                  Stavudine 30mg, capsules, 60 Caps
#
#                          Molecule/Test Type      Brand   Dosage  \
# 0  HIV, Reveal G3 Rapid HIV-1 Antibody Test     Reveal    False
# 1                                Nevirapine    Generic  10mg/ml
# 2       HIV 1/2, Determine Complete HIV Kit  Determine    False
# 3                                Lamivudine    Generic    150mg
# 4                                 Stavudine    Generic     30mg
#
#        Dosage Form  Unit of Measure (Per Pack)  Line Item Value  Pack Price  \
# 0         Test kit                          30            551.0       29.00
# 1  Oral suspension                         180           6200.0        6.20
# 2         Test kit                         100          40000.0       52.00
# 3           Tablet                          60         127360.8        3.99
# 4          Capsule                          60         121600.0        3.20
#
#    Unit Price             Manufacturing Site First Line Designation  \
# 0        0.97     Ranbaxy Fine Chemicals LTD                    Yes
# 1        0.03      Aurobindo Unit III, India                    Yes
# 2        0.80  ABBVIE GmbH & Co.KG Wiesbaden                    Yes
# 3        0.07  Ranbaxy, Paonta Shahib, India                    Yes
# 4        0.05      Aurobindo Unit III, India                    Yes
#
#   Weight (Kilograms) Freight Cost (USD)
# 0                 13             780.34
# 1                358             4521.5
# 2                171            1653.78
# 3               1855           16007.06
# 4               7590           45450.08

# %% [markdown]
# # Conclusion:
# Here our task which we had performed is Data Cleaning or Data Wrangling that consists the process of removing duplicate or irrelevant observations, removing unwanted observations from Dataset, excluding the outliers, handling Missing values and validation.
# And further process has to be done for performing the model creation and deployment is Data exploration and Visualization , Feature Engineering and Feature Scaling and later the model will be developed.

# %%
df.head()
# Out:
#    ID Project Code Performance Qualification Purchase(or)Shipping Order  \
# 0   1   100-CI-T01            Pre-PQ Process                     SCMS-4
# 1   3   108-VN-T01            Pre-PQ Process                    SCMS-13
# 2   4   100-CI-T01            Pre-PQ Process                    SCMS-20
# 3  15   108-VN-T01            Pre-PQ Process                    SCMS-78
# 4  16   108-VN-T01            Pre-PQ Process                    SCMS-81
#
#   Advanced Shipment Notice        Country Managed By  Fulfill Via  \
# 0                    ASN-8  Côte d'Ivoire   PMO - US  Direct Drop
# 1                   ASN-85        Vietnam   PMO - US  Direct Drop
# 2                   ASN-14  Côte d'Ivoire   PMO - US  Direct Drop
# 3                   ASN-50        Vietnam   PMO - US  Direct Drop
# 4                   ASN-55        Vietnam   PMO - US  Direct Drop
#
#   Vendor INCO Term Shipment Mode PQ First Sent to Client Date  \
# 0              EXW           Air               Pre-PQ Process
# 1              EXW           Air               Pre-PQ Process
# 2              FCA           Air               Pre-PQ Process
# 3              EXW           Air               Pre-PQ Process
# 4              EXW           Air               Pre-PQ Process
#
#   PO Sent to Vendor Date Scheduled Delivery Date Delivered to Client Date  \
# 0      Date Not Captured                2-Jun-06                 2-Jun-06
# 1      Date Not Captured               14-Nov-06                14-Nov-06
# 2      Date Not Captured               27-Aug-06                27-Aug-06
# 3      Date Not Captured                1-Sep-06                 1-Sep-06
# 4      Date Not Captured               11-Aug-06                11-Aug-06
#
#   Product Group Sub Classification  \
# 0          HRDT           HIV test
# 1           ARV          Pediatric
# 2          HRDT           HIV test
# 3           ARV              Adult
# 4           ARV              Adult
#
#                                               Vendor  \
# 0                        RANBAXY Fine Chemicals LTD.
# 1                           Aurobindo Pharma Limited
# 2                               Abbott GmbH & Co. KG
# 3  SUN PHARMACEUTICAL INDUSTRIES LTD (RANBAXY LAB...
# 4                           Aurobindo Pharma Limited
#
#                                     Item Description  \
# 0  HIV, Reveal G3 Rapid HIV-1 Antibody Test, 30 T...
# 1  Nevirapine 10mg/ml, oral suspension, Bottle, 2...
# 2     HIV 1/2, Determine Complete HIV Kit, 100 Tests
# 3                 Lamivudine 150mg, tablets, 60 Tabs
# 4                  Stavudine 30mg, capsules, 60 Caps
#
#                          Molecule/Test Type      Brand   Dosage  \
# 0  HIV, Reveal G3 Rapid HIV-1 Antibody Test     Reveal    False
# 1                                Nevirapine    Generic  10mg/ml
# 2       HIV 1/2, Determine Complete HIV Kit  Determine    False
# 3                                Lamivudine    Generic    150mg
# 4                                 Stavudine    Generic     30mg
#
#        Dosage Form  Unit of Measure (Per Pack)  Line Item Value  Pack Price  \
# 0         Test kit                          30            551.0       29.00
# 1  Oral suspension                         180           6200.0        6.20
# 2         Test kit                         100          40000.0       52.00
# 3           Tablet                          60         127360.8        3.99
# 4          Capsule                          60         121600.0        3.20
#
#    Unit Price             Manufacturing Site First Line Designation  \
# 0        0.97     Ranbaxy Fine Chemicals LTD                    Yes
# 1        0.03      Aurobindo Unit III, India                    Yes
# 2        0.80  ABBVIE GmbH & Co.KG Wiesbaden                    Yes
# 3        0.07  Ranbaxy, Paonta Shahib, India                    Yes
# 4        0.05      Aurobindo Unit III, India                    Yes
#
#   Weight (Kilograms) Freight Cost (USD)
# 0                 13             780.34
# 1                358             4521.5
# 2                171            1653.78
# 3               1855           16007.06
# 4               7590           45450.08

# %%
for i in cat_feat.columns:
    print(i,'\n',cat_feat[i].value_counts(),'\n')
# Out:
# Project Code
#  116-ZA-T30    768
# 104-CI-T30    729
# 151-NG-T30    628
# 114-UG-T30    596
# 108-VN-T30    522
#              ...
# 100-GN-T30      1
# 103-CD-T30      1
# 103-UG-T30      1
# 900-GY-T30      1
# 104-SZ-T30      1
# Name: Project Code, Length: 142, dtype: int64
#
# PQ #
#  Pre-PQ Process    2681
# FPQ-14942          205
# FPQ-12522          154
# FPQ-13973          110
# FPQ-4537            98
#                   ...
# FPQ-6977             1
# FPQ-9819             1
# FPQ-6124             1
# FPQ-12838            1
# FPQ-15884            1
# Name: PQ #, Length: 1237, dtype: int64
#
# PO / SO #
#  SCMS-199289    67
# SCMS-199283    63
# SCMS-183950    55
# SCMS-215370    38
# SCMS-259075    38
#                ..
# SO-47850        1
# SCMS-102040     1
# SCMS-103150     1
# SO-40490        1
# SCMS-134290     1
# Name: PO / SO #, Length: 6233, dtype: int64
#
# ASN/DN #
#  ASN-19166    54
# ASN-24415    38
# ASN-23875    26
# ASN-32138    19
# ASN-28036    17
#              ..
# ASN-15388     1
# ASN-6395      1
# ASN-10756     1
# ASN-29936     1
# DN-2406       1
# Name: ASN/DN #, Length: 7030, dtype: int64
#
# Country
#  South Africa          1406
# Nigeria               1194
# Côte d'Ivoire         1083
# Uganda                 779
# Vietnam                688
# Zambia                 683
# Haiti                  655
# Mozambique             631
# Zimbabwe               538
# Tanzania               519
# Rwanda                 430
# Congo, DRC             333
# Guyana                 237
# Ethiopia               216
# South Sudan            164
# Kenya                  111
# Burundi                 98
# Namibia                 95
# Cameroon                75
# Botswana                70
# Ghana                   58
# Dominican Republic      52
# Sudan                   46
# Swaziland               35
# Mali                    17
# Guatemala               15
# Pakistan                15
# Malawi                  14
# Benin                   13
# Libya                    8
# Lebanon                  8
# Angola                   7
# Liberia                  6
# Lesotho                  4
# Sierra Leone             4
# Togo                     3
# Afghanistan              3
# Senegal                  3
# Burkina Faso             2
# Kazakhstan               2
# Kyrgyzstan               2
# Guinea                   1
# Belize                   1
# Name: Country, dtype: int64
#
# Managed By
#  PMO - US                     10265
# South Africa Field Office       57
# Ethiopia Field Office            1
# Haiti Field Office               1
# Name: Managed By, dtype: int64
#
# Fulfill Via
#  From RDC       5404
# Direct Drop    4920
# Name: Fulfill Via, dtype: int64
#
# Vendor INCO Term
#  N/A - From RDC    5404
# EXW               2778
# DDP               1443
# FCA                397
# CIP                275
# DDU                 15
# DAP                  9
# CIF                  3
# Name: Vendor INCO Term, dtype: int64
#
# Shipment Mode
#  Air            6113
# Truck          2830
# Air Charter     650
# Ocean           371
# Name: Shipment Mode, dtype: int64
#
# PQ First Sent to Client Date
#  Pre-PQ Process       2476
# 9/11/14               205
# Date Not Captured     205
# 7/11/13               173
# 4/30/14               123
#                      ...
# 1/3/12                  1
# 4/3/11                  1
# 4/16/15                 1
# 5/31/12                 1
# 8/27/14                 1
# Name: PQ First Sent to Client Date, Length: 765, dtype: int64
#
# PO Sent to Vendor Date
#  N/A - From RDC       5404
# Date Not Captured     328
# 8/27/14                80
# 3/19/10                78
# 8/29/14                76
#                      ...
# 6/2/09                  1
# 11/2/10                 1
# 5/18/15                 1
# 7/6/11                  1
# 3/12/15                 1
# Name: PO Sent to Vendor Date, Length: 897, dtype: int64
#
# Scheduled Delivery Date
#  29-Aug-14    97
# 16-Mar-12    83
# 27-Aug-14    63
# 31-May-10    62
# 31-Jan-14    60
#              ..
# 14-May-13     1
# 25-Jun-07     1
# 19-May-15     1
# 3-Jan-13      1
# 9-Feb-15      1
# Name: Scheduled Delivery Date, Length: 2006, dtype: int64
#
# Delivered to Client Date
#  29-Aug-14    74
# 27-Aug-14    66
# 28-Jun-10    60
# 14-Feb-12    60
# 16-Apr-13    59
#              ..
# 18-Oct-07     1
# 20-Dec-10     1
# 21-Jul-12     1
# 10-May-06     1
# 31-Aug-12     1
# Name: Delivered to Client Date, Length: 2093, dtype: int64
#
# Delivery Recorded Date
#  29-Aug-14    67
# 27-Aug-14    66
# 28-Jun-10    60
# 14-Feb-12    60
# 16-Apr-13    59
#              ..
# 27-Apr-11     1
# 30-May-14     1
# 12-Dec-07     1
# 25-Oct-13     1
# 31-Aug-12     1
# Name: Delivery Recorded Date, Length: 2042, dtype: int64
#
# Product Group
#  ARV     8550
# HRDT    1728
# ANTM      22
# ACT       16
# MRDT       8
# Name: Product Group, dtype: int64
#
# Sub Classification
#  Adult                   6595
# Pediatric               1955
# HIV test                1567
# HIV test - Ancillary     161
# Malaria                   30
# ACT                       16
# Name: Sub Classification, dtype: int64
#
# Vendor
#  SCMS from RDC                           5404
# Orgenics, Ltd                            754
# S. BUYS WHOLESALER                       715
# Aurobindo Pharma Limited                 668
# Trinity Biotech, Plc                     356
#                                         ...
# OMEGA DIAGNOSTICS LTD                      1
# THE MEDICAL EXPORT GROUP BV                1
# CENTRAL PHARMACEUTICAL COMPANY NO. 1       1
# ACCESS BIO, INC.                           1
# RAININ INSTRUMENT, LLC.                    1
# Name: Vendor, Length: 73, dtype: int64
#
# Item Description
#  Efavirenz 600mg, tablets, 30 Tabs                                                755
# Nevirapine 200mg, tablets, 60 Tabs                                               623
# Lamivudine/Zidovudine 150/300mg, tablets, 60 Tabs                                597
# Lamivudine/Nevirapine/Zidovudine 150/200/300mg, tablets, 60 Tabs                 580
# HIV 1/2, Determine Complete HIV Kit, 100 Tests                                   577
#                                                                                 ...
# Lopinavir/Ritonavir 200/50mg, [DON] tablets, 120 Tabs                              1
# Mefloquine 250mg (as hydrochloride), tablets, 100 Tabs                             1
# HIV 1/2, Visitect Kit, 25 Tests                                                    1
# Efavirenz 200mg, tablets, 30 Tabs                                                  1
# Lamivudine/Zidovudine+Abacavir 150/300+300mg, tablets, co-blister, 60+60 Tabs      1
# Name: Item Description, Length: 184, dtype: int64
#
# Molecule/Test Type
#  Efavirenz                                                                                             1125
# Nevirapine                                                                                             877
# Lamivudine/Nevirapine/Zidovudine                                                                       707
# Lamivudine/Zidovudine                                                                                  689
# Lopinavir/Ritonavir                                                                                    633
#                                                                                                       ...
# HIV 1/2, ImmunoComb II BiSpot EIA Kit                                                                    1
# HIV 1/2, Visitect Kit                                                                                    1
# Quinine                                                                                                  1
# HIV 1/2, INSTI HIV 1/2 Antibody Kit                                                                      1
# HIV 1/2, Colloidal Gold, Diagnostic Kit Set (includes lancet, transfer pipette & alcohol prep pad)       1
# Name: Molecule/Test Type, Length: 86, dtype: int64
#
# Brand
#  Generic            7285
# Determine           799
# Uni-Gold            373
# Aluvia              250
# Kaletra             165
# Norvir              136
# Stat-Pak            115
# Bioline             113
# Truvada              94
# Videx                84
# Colloidal Gold       70
# Stocrin/Sustiva      69
# OraQuick             60
# Invirase             53
# Viread               52
# Zerit                46
# Isentress            44
# Epivir               42
# Prezista             42
# Retrovir             41
# Videx EC             41
# Ziagen               37
# Crixivan             36
# Capillus             35
# Intelence            32
# Genie                30
# Viramune             28
# Clearview            19
# Reyataz              18
# Trizivir             18
# Atripla              16
# First Response       15
# Coartem              12
# Viracept             11
# DoubleCheck           5
# Multispot             5
# Paramax               5
# INSTi                 5
# LAV                   4
# Hexagon               3
# Combivir              3
# ImmunoComb            3
# Reveal                3
# InstantCHEK           2
# Bundi                 2
# CareStart             1
# Visitect              1
# Pepti-LAV             1
# Name: Brand, dtype: int64
#
# Dosage
#  300mg              990
# 200mg              932
# 600mg              772
# 150/300mg          600
# 150/300/200mg      580
# 10mg/ml            552
# 150mg              431
# 200/50mg           395
# 300/300mg          301
# 600/300/300mg      286
# 150/200/30mg       250
# 100mg              228
# 50mg               174
# 200/300mg          160
# 80/20mg/ml         158
# 400mg              156
# 20mg/ml            152
# 30mg               144
# 600/200/300mg      139
# 150/30mg           133
# 30/50/60mg         127
# 300/200mg           94
# 30/60mg             89
# 250mg               88
# 100/25mg            73
# 60/30mg             73
# 600/300mg           63
# 1mg/ml              54
# 300/100mg           54
# 20mg                43
# 25mg                39
# 15mg                38
# 30mg/ml             33
# 300/150/300mg       28
# 30/50/6mg           19
# 30/6mg              14
# 500/25mg            13
# 80mg/ml             13
# 60/100/12mg         12
# 20/120mg            12
# 2g                  11
# 500mg               10
# 150/300+200mg        8
# 133.3/33.3mg         7
# 150/300mg+600mg      7
# 40mg                 6
# 150/200/40mg         5
# 60mg                 5
# 60/12mg              5
# 125mg                4
# 50+153mg             4
# 600mg/2ml            2
# 50mg/g               1
# 150/300+300mg        1
# Name: Dosage, dtype: int64
#
# Dosage Form
#  Tablet                                3532
# Tablet - FDC                          2749
# Test kit                              1575
# Capsule                                729
# Oral solution                          727
# Chewable/dispersible tablet - FDC      239
# Oral suspension                        214
# Test kit - Ancillary                   161
# Chewable/dispersible tablet            146
# Delayed-release capsules               131
# Delayed-release capsules - blister      41
# Powder for oral solution                28
# Tablet - FDC + co-blister               20
# Tablet - FDC + blister                  15
# Tablet - blister                        10
# Injection                                6
# Oral powder                              1
# Name: Dosage Form, dtype: int64
#
# Manufacturing Site
#  Aurobindo Unit III, India              3172
# Mylan (formerly Matrix) Nashik         1415
# Hetero Unit III Hyderabad IN            869
# Cipla, Goa, India                       665
# Strides, Bangalore, India.              540
#                                        ...
# BUNDI INTERNATIONAL DIAGNOSTICS LTD       1
# MedMira Inc.                              1
# Meditab (for Cipla) Daman IN              1
# Gland Pharma Ltd Pally Factory            1
# GSK Barnard Castle UK                     1
# Name: Manufacturing Site, Length: 88, dtype: int64
#
# First Line Designation
#  Yes    7030
# No     3294
# Name: First Line Designation, dtype: int64
#
# Weight (Kilograms)
#  Weight Captured Separately    1507
# 2                               29
# 6                               26
# 1                               23
# 5                               20
#                               ...
# 14340                            1
# 4382                             1
# See ASN-26283 (ID#:46875)        1
# See ASN-10816 (ID#:28664)        1
# 4091                             1
# Name: Weight (Kilograms), Length: 4688, dtype: int64
#
# Freight Cost (USD)
#  Freight Included in Commodity Cost    1442
# Invoiced Separately                    239
# 9736.1                                  36
# 6147.18                                 27
# 7445.8                                  16
#                                       ...
# See DN-3744 (ID#:85483)                  1
# See ASN-33146 (ID#:44860)                1
# 1400                                     1
# 729.03                                   1
# 1572.92                                  1
# Name: Freight Cost (USD), Length: 6733, dtype: int64

# %%
new_df=df[['Purchase(or)Shipping Order','Item Description']]
new_df
# Out:
#       Purchase(or)Shipping Order  \
# 0                         SCMS-4
# 1                        SCMS-13
# 2                        SCMS-20
# 3                        SCMS-78
# 4                        SCMS-81
# ...                          ...
# 10319                   SO-50020
# 10320                   SO-50102
# 10321                   SO-49600
# 10322                   SO-51680
# 10323                   SO-50022
#
#                                         Item Description
# 0      HIV, Reveal G3 Rapid HIV-1 Antibody Test, 30 T...
# 1      Nevirapine 10mg/ml, oral suspension, Bottle, 2...
# 2         HIV 1/2, Determine Complete HIV Kit, 100 Tests
# 3                     Lamivudine 150mg, tablets, 60 Tabs
# 4                      Stavudine 30mg, capsules, 60 Caps
# ...                                                  ...
# 10319  Lamivudine/Nevirapine/Zidovudine 30/50/60mg, d...
# 10320  Lamivudine/Zidovudine 150/300mg, tablets, 60 Tabs
# 10321  Efavirenz/Lamivudine/Tenofovir Disoproxil Fuma...
# 10322  Lamivudine/Zidovudine 150/300mg, tablets, 60 Tabs
# 10323  Lamivudine/Zidovudine 30/60mg, dispersible tab...
#
# [10324 rows x 2 columns]

# %%
dff=df[df['Purchase(or)Shipping Order']=='SCMS-199289']
dff['Item Description'].unique()
# Out:
# array(['Lamivudine 10mg/ml, oral solution w/syringe, Bottle, 240 ml',
#        'Tenofovir Disoproxil Fumarate 300mg, tablets, 30 Tabs',
#        'Didanosine 400mg, delayed-release capsules, 30 Caps',
#        'Zidovudine 300mg, tablets, 60 Tabs',
#        'Lamivudine/Zidovudine 150/300mg, tablets, 60 Tabs',
#        'Efavirenz 50mg, capsule, 30 Caps',
#        'Lopinavir/Ritonavir 200/50mg [Aluvia], tablets, 120 Tabs',
#        'Efavirenz 600mg, tablets, 30 Tabs',
#        'Lamivudine 150mg, tablets, 60 Tabs',
#        'Nevirapine 200mg, tablets, 60 Tabs',
#        'Efavirenz 200mg, capsule, 90 Caps',
#        'Didanosine 250mg, delayed-release capsules, 30 Caps',
#        'Lopinavir/Ritonavir 100/25mg [Aluvia], tablets, 60 Tabs',
#        'Abacavir 300mg, tablets, 60 Tabs',
#        'Emtricitabine/Tenofovir Disoproxil Fumarate 200/300mg, tablets, 30 Tabs',
#        'Abacavir 20mg/ml, oral solution w/syringe, Bottle, 240 ml',
#        'Lamivudine/Nevirapine/Stavudine 150/200/30mg, tablets, 60 Tabs'],
#       dtype=object)

# %%
df_2=df[df['Purchase(or)Shipping Order']=='SCMS-199283']
df_2['Item Description'].unique()
# Out:
# array(['Emtricitabine/Tenofovir Disoproxil Fumarate 200/300mg, tablets, 30 Tabs',
#        'Zidovudine 300mg, tablets, 60 Tabs',
#        'Lopinavir/Ritonavir 200/50mg [Aluvia], tablets, 120 Tabs',
#        'Efavirenz 600mg, tablets, 30 Tabs',
#        'Lamivudine/Zidovudine 150/300mg, tablets, 60 Tabs',
#        'Tenofovir Disoproxil Fumarate 300mg, tablets, 30 Tabs',
#        'Lamivudine 150mg, tablets, 60 Tabs',
#        'Lamivudine 10mg/ml, oral solution w/syringe, Bottle, 240 ml',
#        'Efavirenz 200mg, capsule, 90 Caps',
#        'Abacavir 20mg/ml, oral solution w/syringe, Bottle, 240 ml',
#        'Didanosine 250mg, delayed-release capsules, 30 Caps',
#        'Efavirenz 50mg, capsule, 30 Caps',
#        'Didanosine 400mg, delayed-release capsules, 30 Caps',
#        'Abacavir 300mg, tablets, 60 Tabs',
#        'Nevirapine 200mg, tablets, 60 Tabs'], dtype=object)

# %%
df['Purchase(or)Shipping Order'].value_counts()
# Out:
# SCMS-199289    67
# SCMS-199283    63
# SCMS-183950    55
# SCMS-215370    38
# SCMS-259075    38
#                ..
# SO-47850        1
# SCMS-102040     1
# SCMS-103150     1
# SO-40490        1
# SCMS-134290     1
# Name: Purchase(or)Shipping Order, Length: 6233, dtype: int64

# %%
df[df['Project Code']=='100-CI-T01']
# Out:
#          ID Project Code Performance Qualification Purchase(or)Shipping Order  \
# 0         1   100-CI-T01            Pre-PQ Process                     SCMS-4
# 2         4   100-CI-T01            Pre-PQ Process                    SCMS-20
# 129    1245   100-CI-T01            Pre-PQ Process                     SCMS-1
# 412    3926   100-CI-T01            Pre-PQ Process                     SCMS-2
# 522    5233   100-CI-T01            Pre-PQ Process                     SCMS-3
# 1026  10540   100-CI-T01            Pre-PQ Process                     SO-283
# 1035  10550   100-CI-T01            Pre-PQ Process                     SO-284
# 1036  10551   100-CI-T01            Pre-PQ Process                     SO-436
# 1217  10811   100-CI-T01            Pre-PQ Process                     SO-350
# 1227  10824   100-CI-T01            Pre-PQ Process                     SO-430
# 1424  11086   100-CI-T01            Pre-PQ Process                     SO-283
# 1425  11088   100-CI-T01            Pre-PQ Process                     SO-283
# 1428  11091   100-CI-T01            Pre-PQ Process                     SO-373
# 1429  11092   100-CI-T01            Pre-PQ Process                     SO-373
# 1436  11102   100-CI-T01            Pre-PQ Process                     SO-392
# 1441  11113   100-CI-T01            Pre-PQ Process                     SO-394
# 1607  11368   100-CI-T01            Pre-PQ Process                     SO-373
# 1608  11369   100-CI-T01            Pre-PQ Process                     SO-373
# 1611  11373   100-CI-T01            Pre-PQ Process                     SO-397
# 1612  11374   100-CI-T01            Pre-PQ Process                     SO-286
# 1621  11386   100-CI-T01            Pre-PQ Process                     SO-438
# 1839  11703   100-CI-T01            Pre-PQ Process                     SO-283
# 1847  11713   100-CI-T01            Pre-PQ Process                     SO-391
# 1848  11714   100-CI-T01            Pre-PQ Process                     SO-286
# 1851  11718   100-CI-T01            Pre-PQ Process                     SO-439
# 1853  11721   100-CI-T01            Pre-PQ Process                     SO-393
# 1854  11722   100-CI-T01            Pre-PQ Process                     SO-440
# 1855  11723   100-CI-T01            Pre-PQ Process                     SO-435
# 2068  12025   100-CI-T01            Pre-PQ Process                     SO-283
# 2069  12026   100-CI-T01            Pre-PQ Process                     SO-283
# 2073  12034   100-CI-T01            Pre-PQ Process                     SO-390
# 2074  12037   100-CI-T01            Pre-PQ Process                     SO-284
# 2076  12043   100-CI-T01            Pre-PQ Process                     SO-437
# 2077  12044   100-CI-T01            Pre-PQ Process                     SO-411
# 2078  12045   100-CI-T01            Pre-PQ Process                     SO-285
# 2079  12046   100-CI-T01            Pre-PQ Process                     SO-285
# 2080  12047   100-CI-T01            Pre-PQ Process                     SO-431
# 2290  12349   100-CI-T01            Pre-PQ Process                     SO-434
# 2493  12648   100-CI-T01            Pre-PQ Process                     SO-433
# 2494  12649   100-CI-T01            Pre-PQ Process                     SO-432
#
#      Advanced Shipment Notice        Country Managed By  Fulfill Via  \
# 0                       ASN-8  Côte d'Ivoire   PMO - US  Direct Drop
# 2                      ASN-14  Côte d'Ivoire   PMO - US  Direct Drop
# 129                     ASN-5  Côte d'Ivoire   PMO - US  Direct Drop
# 412                     ASN-4  Côte d'Ivoire   PMO - US  Direct Drop
# 522                     ASN-6  Côte d'Ivoire   PMO - US  Direct Drop
# 1026                    DN-16  Côte d'Ivoire   PMO - US     From RDC
# 1035                    DN-46  Côte d'Ivoire   PMO - US     From RDC
# 1036                    DN-73  Côte d'Ivoire   PMO - US     From RDC
# 1217                    DN-28  Côte d'Ivoire   PMO - US     From RDC
# 1227                    DN-75  Côte d'Ivoire   PMO - US     From RDC
# 1424                    DN-16  Côte d'Ivoire   PMO - US     From RDC
# 1425                    DN-26  Côte d'Ivoire   PMO - US     From RDC
# 1428                    DN-30  Côte d'Ivoire   PMO - US     From RDC
# 1429                    DN-30  Côte d'Ivoire   PMO - US     From RDC
# 1436                    DN-53  Côte d'Ivoire   PMO - US     From RDC
# 1441                    DN-61  Côte d'Ivoire   PMO - US     From RDC
# 1607                    DN-30  Côte d'Ivoire   PMO - US     From RDC
# 1608                    DN-30  Côte d'Ivoire   PMO - US     From RDC
# 1611                    DN-54  Côte d'Ivoire   PMO - US     From RDC
# 1612                    DN-71  Côte d'Ivoire   PMO - US     From RDC
# 1621                    DN-80  Côte d'Ivoire   PMO - US     From RDC
# 1839                    DN-16  Côte d'Ivoire   PMO - US     From RDC
# 1847                    DN-52  Côte d'Ivoire   PMO - US     From RDC
# 1848                    DN-71  Côte d'Ivoire   PMO - US     From RDC
# 1851                    DN-86  Côte d'Ivoire   PMO - US     From RDC
# 1853                    DN-62  Côte d'Ivoire   PMO - US     From RDC
# 1854                    DN-79  Côte d'Ivoire   PMO - US     From RDC
# 1855                    DN-81  Côte d'Ivoire   PMO - US     From RDC
# 2068                    DN-16  Côte d'Ivoire   PMO - US     From RDC
# 2069                    DN-16  Côte d'Ivoire   PMO - US     From RDC
# 2073                    DN-51  Côte d'Ivoire   PMO - US     From RDC
# 2074                    DN-46  Côte d'Ivoire   PMO - US     From RDC
# 2076                    DN-85  Côte d'Ivoire   PMO - US     From RDC
# 2077                    DN-60  Côte d'Ivoire   PMO - US     From RDC
# 2078                    DN-74  Côte d'Ivoire   PMO - US     From RDC
# 2079                    DN-74  Côte d'Ivoire   PMO - US     From RDC
# 2080                    DN-76  Côte d'Ivoire   PMO - US     From RDC
# 2290                    DN-78  Côte d'Ivoire   PMO - US     From RDC
# 2493                    DN-77  Côte d'Ivoire   PMO - US     From RDC
# 2494                    DN-82  Côte d'Ivoire   PMO - US     From RDC
#
#      Vendor INCO Term            Shipment Mode PQ First Sent to Client Date  \
# 0                 EXW                      Air               Pre-PQ Process
# 2                 FCA                      Air               Pre-PQ Process
# 129               EXW                      Air               Pre-PQ Process
# 412               EXW                      Air               Pre-PQ Process
# 522               EXW                      Air               Pre-PQ Process
# 1026   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 1035   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 1036   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 1217   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 1227   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 1424   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 1425   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 1428   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 1429   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 1436   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 1441   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 1607   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 1608   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 1611   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 1612   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 1621   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 1839   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 1847   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 1848   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 1851   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 1853   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 1854   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 1855   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 2068   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 2069   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 2073   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 2074   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 2076   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 2077   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 2078   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 2079   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 2080   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 2290   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 2493   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
# 2494   N/A - From RDC  0    Air\ndtype: object               Pre-PQ Process
#
#      PO Sent to Vendor Date Scheduled Delivery Date Delivered to Client Date  \
# 0         Date Not Captured                2-Jun-06                 2-Jun-06
# 2         Date Not Captured               27-Aug-06                27-Aug-06
# 129                 4/19/06               27-Jun-06                27-Jun-06
# 412       Date Not Captured               10-May-06                10-May-06
# 522       Date Not Captured                2-May-06                 2-May-06
# 1026         N/A - From RDC               22-Feb-07                22-Feb-07
# 1035         N/A - From RDC                4-May-07                 4-May-07
# 1036         N/A - From RDC               30-Apr-07                30-Apr-07
# 1217         N/A - From RDC                8-Mar-07                 8-Mar-07
# 1227         N/A - From RDC               30-Apr-07                30-Apr-07
# 1424         N/A - From RDC               22-Feb-07                22-Feb-07
# 1425         N/A - From RDC               22-Feb-07                 8-Mar-07
# 1428         N/A - From RDC               15-Mar-07                15-Mar-07
# 1429         N/A - From RDC               15-Mar-07                15-Mar-07
# 1436         N/A - From RDC                4-May-07                 4-May-07
# 1441         N/A - From RDC                4-May-07                 4-May-07
# 1607         N/A - From RDC               15-Mar-07                15-Mar-07
# 1608         N/A - From RDC               15-Mar-07                15-Mar-07
# 1611         N/A - From RDC                4-May-07                 4-May-07
# 1612         N/A - From RDC               30-Apr-07                30-Apr-07
# 1621         N/A - From RDC               30-Apr-07                30-Apr-07
# 1839         N/A - From RDC               22-Feb-07                22-Feb-07
# 1847         N/A - From RDC                4-May-07                 4-May-07
# 1848         N/A - From RDC               30-Apr-07                30-Apr-07
# 1851         N/A - From RDC               30-Apr-07                30-Apr-07
# 1853         N/A - From RDC                4-May-07                 4-May-07
# 1854         N/A - From RDC               30-Apr-07                30-Apr-07
# 1855         N/A - From RDC               30-Apr-07                30-Apr-07
# 2068         N/A - From RDC               22-Feb-07                22-Feb-07
# 2069         N/A - From RDC               22-Feb-07                22-Feb-07
# 2073         N/A - From RDC                4-May-07                 4-May-07
# 2074         N/A - From RDC                4-May-07                 4-May-07
# 2076         N/A - From RDC               30-Apr-07                30-Apr-07
# 2077         N/A - From RDC                4-May-07                 4-May-07
# 2078         N/A - From RDC               30-Apr-07                30-Apr-07
# 2079         N/A - From RDC               30-Apr-07                30-Apr-07
# 2080         N/A - From RDC               30-Apr-07                30-Apr-07
# 2290         N/A - From RDC               30-Apr-07                30-Apr-07
# 2493         N/A - From RDC               30-Apr-07                30-Apr-07
# 2494         N/A - From RDC               30-Apr-07                30-Apr-07
#
#      Product Group Sub Classification                         Vendor  \
# 0             HRDT           HIV test    RANBAXY Fine Chemicals LTD.
# 2             HRDT           HIV test           Abbott GmbH & Co. KG
# 129           HRDT           HIV test  BIO-RAD LABORATORIES (FRANCE)
# 412           HRDT           HIV test          OMEGA DIAGNOSTICS LTD
# 522           HRDT           HIV test     Standard Diagnostics, Inc.
# 1026           ARV              Adult                  SCMS from RDC
# 1035           ARV              Adult                  SCMS from RDC
# 1036           ARV              Adult                  SCMS from RDC
# 1217           ARV              Adult                  SCMS from RDC
# 1227           ARV              Adult                  SCMS from RDC
# 1424           ARV              Adult                  SCMS from RDC
# 1425           ARV              Adult                  SCMS from RDC
# 1428           ARV              Adult                  SCMS from RDC
# 1429           ARV              Adult                  SCMS from RDC
# 1436           ARV              Adult                  SCMS from RDC
# 1441           ARV              Adult                  SCMS from RDC
# 1607           ARV              Adult                  SCMS from RDC
# 1608           ARV              Adult                  SCMS from RDC
# 1611           ARV              Adult                  SCMS from RDC
# 1612           ARV              Adult                  SCMS from RDC
# 1621           ARV              Adult                  SCMS from RDC
# 1839           ARV              Adult                  SCMS from RDC
# 1847           ARV              Adult                  SCMS from RDC
# 1848           ARV              Adult                  SCMS from RDC
# 1851           ARV              Adult                  SCMS from RDC
# 1853           ARV              Adult                  SCMS from RDC
# 1854           ARV              Adult                  SCMS from RDC
# 1855           ARV              Adult                  SCMS from RDC
# 2068           ARV              Adult                  SCMS from RDC
# 2069           ARV              Adult                  SCMS from RDC
# 2073           ARV              Adult                  SCMS from RDC
# 2074           ARV              Adult                  SCMS from RDC
# 2076           ARV              Adult                  SCMS from RDC
# 2077           ARV              Adult                  SCMS from RDC
# 2078           ARV              Adult                  SCMS from RDC
# 2079           ARV              Adult                  SCMS from RDC
# 2080           ARV              Adult                  SCMS from RDC
# 2290           ARV              Adult                  SCMS from RDC
# 2493           ARV              Adult                  SCMS from RDC
# 2494           ARV              Adult                  SCMS from RDC
#
#                                        Item Description  \
# 0     HIV, Reveal G3 Rapid HIV-1 Antibody Test, 30 T...
# 2        HIV 1/2, Determine Complete HIV Kit, 100 Tests
# 129   #108853** HIV, Genie II HIV-1/HIV-2 Kit, 40 Tests
# 412                     HIV 1/2, Visitect Kit, 25 Tests
# 522   HIV 1/2, Bioline 3.0 Kit, (no accessories), 30...
# 1026  Lamivudine/Zidovudine 150/300mg, tablets, 60 Tabs
# 1035  Lamivudine/Zidovudine 150/300mg, tablets, 60 Tabs
# 1036  Lamivudine/Nevirapine/Stavudine 150/200/30mg, ...
# 1217  Ritonavir 100mg [Norvir], capsules, cool, 4 x ...
# 1227  Lamivudine/Zidovudine 150/300mg, tablets, 60 Tabs
# 1424                  Efavirenz 600mg, tablets, 30 Tabs
# 1425                  Efavirenz 600mg, tablets, 30 Tabs
# 1428  Tenofovir Disoproxil Fumarate 300mg [Viread], ...
# 1429    Saquinavir 200mg [Invirase], capsules, 270 Caps
# 1436                  Efavirenz 600mg, tablets, 30 Tabs
# 1441  Lamivudine/Zidovudine 150/300mg, tablets, 60 Tabs
# 1607     Indinavir 400mg [Crixivan], capsules, 180 Caps
# 1608                   Abacavir 300mg, tablets, 60 Tabs
# 1611                  Efavirenz 600mg, tablets, 30 Tabs
# 1612     Indinavir 400mg [Crixivan], capsules, 180 Caps
# 1621  Lamivudine/Nevirapine/Stavudine 150/200/30mg, ...
# 1839  Tenofovir Disoproxil Fumarate 300mg [Viread], ...
# 1847                  Efavirenz 600mg, tablets, 30 Tabs
# 1848                   Abacavir 300mg, tablets, 60 Tabs
# 1851  Lamivudine/Nevirapine/Stavudine 150/200/30mg, ...
# 1853  Lamivudine/Zidovudine 150/300mg, tablets, 60 Tabs
# 1854  Lamivudine/Nevirapine/Stavudine 150/200/30mg, ...
# 1855  Lamivudine/Nevirapine/Stavudine 150/200/30mg, ...
# 2068                  Efavirenz 600mg, tablets, 30 Tabs
# 2069  Lamivudine/Zidovudine 150/300mg, tablets, 60 Tabs
# 2073                  Efavirenz 600mg, tablets, 30 Tabs
# 2074                  Efavirenz 600mg, tablets, 30 Tabs
# 2076  Lamivudine/Nevirapine/Stavudine 150/200/30mg, ...
# 2077  Lamivudine/Zidovudine 150/300mg, tablets, 60 Tabs
# 2078  Tenofovir Disoproxil Fumarate 300mg [Viread], ...
# 2079  Lamivudine/Zidovudine 150/300mg, tablets, 60 Tabs
# 2080                  Efavirenz 600mg, tablets, 30 Tabs
# 2290                  Efavirenz 600mg, tablets, 30 Tabs
# 2493                  Efavirenz 600mg, tablets, 30 Tabs
# 2494  Lamivudine/Nevirapine/Stavudine 150/200/30mg, ...
#
#                              Molecule/Test Type      Brand        Dosage  \
# 0      HIV, Reveal G3 Rapid HIV-1 Antibody Test     Reveal         False
# 2           HIV 1/2, Determine Complete HIV Kit  Determine         False
# 129               HIV, Genie II HIV-1/HIV-2 Kit      Genie         False
# 412                       HIV 1/2, Visitect Kit   Visitect         False
# 522   HIV 1/2, Bioline 3.0 Kit (no accessories)    Bioline         False
# 1026                      Lamivudine/Zidovudine    Generic     150/300mg
# 1035                      Lamivudine/Zidovudine    Generic     150/300mg
# 1036            Lamivudine/Nevirapine/Stavudine    Generic  150/200/30mg
# 1217                                  Ritonavir     Norvir         100mg
# 1227                      Lamivudine/Zidovudine    Generic     150/300mg
# 1424                                  Efavirenz    Generic         600mg
# 1425                                  Efavirenz    Generic         600mg
# 1428              Tenofovir Disoproxil Fumarate     Viread         300mg
# 1429                                 Saquinavir   Invirase         200mg
# 1436                                  Efavirenz    Generic         600mg
# 1441                      Lamivudine/Zidovudine    Generic     150/300mg
# 1607                                  Indinavir   Crixivan         400mg
# 1608                                   Abacavir    Generic         300mg
# 1611                                  Efavirenz    Generic         600mg
# 1612                                  Indinavir   Crixivan         400mg
# 1621            Lamivudine/Nevirapine/Stavudine    Generic  150/200/30mg
# 1839              Tenofovir Disoproxil Fumarate     Viread         300mg
# 1847                                  Efavirenz    Generic         600mg
# 1848                                   Abacavir    Generic         300mg
# 1851            Lamivudine/Nevirapine/Stavudine    Generic  150/200/30mg
# 1853                      Lamivudine/Zidovudine    Generic     150/300mg
# 1854            Lamivudine/Nevirapine/Stavudine    Generic  150/200/30mg
# 1855            Lamivudine/Nevirapine/Stavudine    Generic  150/200/30mg
# 2068                                  Efavirenz    Generic         600mg
# 2069                      Lamivudine/Zidovudine    Generic     150/300mg
# 2073                                  Efavirenz    Generic         600mg
# 2074                                  Efavirenz    Generic         600mg
# 2076            Lamivudine/Nevirapine/Stavudine    Generic  150/200/30mg
# 2077                      Lamivudine/Zidovudine    Generic     150/300mg
# 2078              Tenofovir Disoproxil Fumarate     Viread         300mg
# 2079                      Lamivudine/Zidovudine    Generic     150/300mg
# 2080                                  Efavirenz    Generic         600mg
# 2290                                  Efavirenz    Generic         600mg
# 2493                                  Efavirenz    Generic         600mg
# 2494            Lamivudine/Nevirapine/Stavudine    Generic  150/200/30mg
#
#        Dosage Form  Unit of Measure (Per Pack)  Line Item Value  Pack Price  \
# 0         Test kit                          30           551.00       29.00
# 2         Test kit                         100         40000.00       52.00
# 129       Test kit                          40         11076.45       52.00
# 412       Test kit                          25          1375.00       31.25
# 522       Test kit                          30           734.70       23.70
# 1026  Tablet - FDC                          60         22857.50       10.25
# 1035  Tablet - FDC                          60         18224.50       10.25
# 1036  Tablet - FDC                          60         67500.00        7.50
# 1217       Capsule                         180         13809.60       38.36
# 1227  Tablet - FDC                          60         71186.25       10.25
# 1424        Tablet                          30         70687.50       16.25
# 1425        Tablet                          30         49140.00       16.25
# 1428        Tablet                          30          8976.00       17.00
# 1429       Capsule                         180         37596.00       52.00
# 1436        Tablet                          30        162500.00       16.25
# 1441  Tablet - FDC                          60        102500.00       10.25
# 1607       Capsule                         180         18248.40       49.32
# 1608        Tablet                          60          1453.65       44.05
# 1611        Tablet                          30         73125.00       16.25
# 1612       Capsule                         180         36496.80       49.32
# 1621  Tablet - FDC                          60         67500.00        7.50
# 1839        Tablet                          30          6528.00       17.00
# 1847        Tablet                          30        162500.00       16.25
# 1848        Tablet                          60          2995.40       44.05
# 1851  Tablet - FDC                          60         67500.00        7.50
# 1853  Tablet - FDC                          60        102500.00       10.25
# 1854  Tablet - FDC                          60          7500.00        7.50
# 1855  Tablet - FDC                          60         67500.00        7.50
# 2068        Tablet                          30          8043.75       16.25
# 2069  Tablet - FDC                          60         28392.50       10.25
# 2073        Tablet                          30        162500.00       16.25
# 2074        Tablet                          30        105933.75       16.25
# 2076  Tablet - FDC                          60         67500.00        7.50
# 2077  Tablet - FDC                          60         10250.00       10.25
# 2078        Tablet                          30          7752.00       17.00
# 2079  Tablet - FDC                          60         71176.00       10.25
# 2080        Tablet                          30        132405.00       16.25
# 2290        Tablet                          30        132405.00       16.25
# 2493        Tablet                          30        132405.00       16.25
# 2494  Tablet - FDC                          60         67500.00        7.50
#
#       Unit Price              Manufacturing Site First Line Designation  \
# 0           0.97      Ranbaxy Fine Chemicals LTD                    Yes
# 2           0.80   ABBVIE GmbH & Co.KG Wiesbaden                    Yes
# 129         1.00            Bio-Rad Laboratories                    Yes
# 412         1.00           OMEGA Diagnostics, UK                    Yes
# 522         0.79     Standard Diagnostics, Korea                    Yes
# 1026        0.17       Aurobindo Unit III, India                    Yes
# 1035        0.17       Aurobindo Unit III, India                    Yes
# 1036        0.12               Cipla, Goa, India                    Yes
# 1217        0.11          ABBVIE (Abbott) France                    Yes
# 1227        0.17       Aurobindo Unit III, India                    Yes
# 1424        0.54       Aurobindo Unit III, India                     No
# 1425        0.54       Aurobindo Unit III, India                    Yes
# 1428        0.57  Gilead(Nycomed) Oranienburg DE                    Yes
# 1429        0.29                     Roche Basel                     No
# 1436        0.54       Aurobindo Unit III, India                    Yes
# 1441        0.17       Aurobindo Unit III, India                    Yes
# 1607        0.27                  MSD Elkton USA                     No
# 1608        0.73       Aurobindo Unit III, India                     No
# 1611        0.54       Aurobindo Unit III, India                    Yes
# 1612        0.27                  MSD Elkton USA                    Yes
# 1621        0.12               Cipla, Goa, India                    Yes
# 1839        0.57  Gilead(Nycomed) Oranienburg DE                     No
# 1847        0.54       Aurobindo Unit III, India                    Yes
# 1848        0.73       Aurobindo Unit III, India                     No
# 1851        0.12               Cipla, Goa, India                    Yes
# 1853        0.17       Aurobindo Unit III, India                    Yes
# 1854        0.12               Cipla, Goa, India                    Yes
# 1855        0.12               Cipla, Goa, India                    Yes
# 2068        0.54       Aurobindo Unit III, India                     No
# 2069        0.17       Aurobindo Unit III, India                     No
# 2073        0.54       Aurobindo Unit III, India                    Yes
# 2074        0.54       Aurobindo Unit III, India                     No
# 2076        0.12               Cipla, Goa, India                    Yes
# 2077        0.17       Aurobindo Unit III, India                    Yes
# 2078        0.57  Gilead(Nycomed) Oranienburg DE                    Yes
# 2079        0.17       Aurobindo Unit III, India                     No
# 2080        0.54       Aurobindo Unit III, India                    Yes
# 2290        0.54       Aurobindo Unit III, India                    Yes
# 2493        0.54       Aurobindo Unit III, India                    Yes
# 2494        0.12               Cipla, Goa, India                    Yes
#
#          Weight (Kilograms)     Freight Cost (USD)
# 0                        13                 780.34
# 2                       171                1653.78
# 129                     165                1816.57
# 412                      15                 633.73
# 522                      11                 515.32
# 1026                    909                   2804
# 1035                    716                   2601
# 1036                    974                   3166
# 1217                    630                 3660.4
# 1227                    650                   2457
# 1424  See DN-16 (ID#:10540)  See DN-16 (ID#:10540)
# 1425                    275                   1448
# 1428                    368                   1619
# 1429  See DN-30 (ID#:11091)  See DN-30 (ID#:11091)
# 1436                    901                   3006
# 1441                    980                   3179
# 1607  See DN-30 (ID#:11091)  See DN-30 (ID#:11091)
# 1608  See DN-30 (ID#:11091)  See DN-30 (ID#:11091)
# 1611                    410                   1931
# 1612                    206                   1583
# 1621                    974                   3166
# 1839  See DN-16 (ID#:10540)  See DN-16 (ID#:10540)
# 1847                    910                   3026
# 1848  See DN-71 (ID#:11374)  See DN-71 (ID#:11374)
# 1851                    992                   3205
# 1853                    963                   3142
# 1854                    104                   1458
# 1855                    969                   3155
# 2068  See DN-16 (ID#:10540)  See DN-16 (ID#:10540)
# 2069  See DN-16 (ID#:10540)  See DN-16 (ID#:10540)
# 2073                    898                   3002
# 2074  See DN-46 (ID#:10550)  See DN-46 (ID#:10550)
# 2076                    972                   3162
# 2077                    114                   1470
# 2078                    682                   2527
# 2079  See DN-74 (ID#:12045)  See DN-74 (ID#:12045)
# 2080                    741                   2656
# 2290                    742                   2658
# 2493                    743                   2660
# 2494                    974                   3166

# %%
df[df['Project Code']=='100-CI-T01'].shape
# Out:
# (40, 30)
